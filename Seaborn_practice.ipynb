# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Seaborn practice

# %% [markdown]
# Load data in Pandas dataframe

# %%
import pandas as pd

# %% [markdown]
# Load data file

# %%
playstore_data = pd.read_csv("googleplaystore.csv")
playstore_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring       ART_AND_DESIGN
# 15                       Learn To Draw Kawaii Characters       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas       ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# 20                           Logo Maker - Small Business       ART_AND_DESIGN
# 21             Boys Photo Editor - Six Pack & Men's Suit       ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds       ART_AND_DESIGN
# 23                                Mcqueen Coloring pages       ART_AND_DESIGN
# 24                           HD Mickey Minnie Wallpapers       ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD       ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring       ART_AND_DESIGN
# 27                                 Animated Photo Editor       ART_AND_DESIGN
# 28                                 Pencil Sketch Drawing       ART_AND_DESIGN
# 29                       Easy Realistic Drawing Tutorial       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10811                                        FR Plus 1.6    AUTO_AND_VEHICLES
# 10812                                      Fr Agnel Pune               FAMILY
# 10813                                     DICT.fr Mobile             BUSINESS
# 10814                               FR: My Secret Pets!                FAMILY
# 10815                          Golden Dictionary (FR-AR)  BOOKS_AND_REFERENCE
# 10816                                 FieldBi FR Offline             BUSINESS
# 10817                               HTC Sense Input - FR                TOOLS
# 10818                               Gold Quote - Gold.fr              FINANCE
# 10819                                          Fanfic-FR  BOOKS_AND_REFERENCE
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10821                                            Poop FR               FAMILY
# 10822                                          PLMGSS FR         PRODUCTIVITY
# 10823                                       List iptv FR        VIDEO_PLAYERS
# 10824                                          Cardio-FR              MEDICAL
# 10825                                 Naruto & Boruto FR               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10827                                 Fr Agnel Ambarnath               FAMILY
# 10828                            Manga-FR - Anime Vostfr               COMICS
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10830                                  News Minecraft.fr   NEWS_AND_MAGAZINES
# 10831                           payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                           FR Tides              WEATHER
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10835                                           FR Forms             BUSINESS
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# 5         4.4     167                5.6M      50,000+  Free     0
# 6         3.8     178                 19M      50,000+  Free     0
# 7         4.1   36815                 29M   1,000,000+  Free     0
# 8         4.4   13791                 33M   1,000,000+  Free     0
# 9         4.7     121                3.1M      10,000+  Free     0
# 10        4.4   13880                 28M   1,000,000+  Free     0
# 11        4.4    8788                 12M   1,000,000+  Free     0
# 12        4.2   44829                 20M  10,000,000+  Free     0
# 13        4.6    4326                 21M     100,000+  Free     0
# 14        4.4    1518                 37M     100,000+  Free     0
# 15        3.2      55                2.7M       5,000+  Free     0
# 16        4.7    3632                5.5M     500,000+  Free     0
# 17        4.5      27                 17M      10,000+  Free     0
# 18        4.3  194216                 39M   5,000,000+  Free     0
# 19        4.6  224399                 31M  10,000,000+  Free     0
# 20        4.0     450                 14M     100,000+  Free     0
# 21        4.1     654                 12M     100,000+  Free     0
# 22        4.7    7699                4.2M     500,000+  Free     0
# 23        NaN      61                7.0M     100,000+  Free     0
# 24        4.7     118                 23M      50,000+  Free     0
# 25        4.8     192                6.0M      10,000+  Free     0
# 26        4.7   20260                 25M     500,000+  Free     0
# 27        4.1     203                6.1M     100,000+  Free     0
# 28        3.9     136                4.6M      10,000+  Free     0
# 29        4.1     223                4.2M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10811     NaN       4                3.9M         100+  Free     0
# 10812     4.1      80                 13M       1,000+  Free     0
# 10813     NaN      20                2.7M      10,000+  Free     0
# 10814     4.0     785                 31M      50,000+  Free     0
# 10815     4.2    5775                4.9M     500,000+  Free     0
# 10816     NaN       2                6.8M         100+  Free     0
# 10817     4.0     885                8.0M     100,000+  Free     0
# 10818     NaN      96                1.5M      10,000+  Free     0
# 10819     3.3      52                3.6M       5,000+  Free     0
# 10820     5.0      22                8.6M       1,000+  Free     0
# 10821     NaN       6                2.5M          50+  Free     0
# 10822     NaN       0                3.1M          10+  Free     0
# 10823     NaN       1                2.9M         100+  Free     0
# 10824     NaN      67                 82M      10,000+  Free     0
# 10825     NaN       7                7.7M         100+  Free     0
# 10826     4.0   88486  Varies with device   5,000,000+  Free     0
# 10827     4.2     117                 13M       5,000+  Free     0
# 10828     3.4     291                 13M      10,000+  Free     0
# 10829     4.6     603                7.4M      10,000+  Free     0
# 10830     3.8     881                2.3M     100,000+  Free     0
# 10831     NaN      38                9.8M       5,000+  Free     0
# 10832     3.8    1195                582k     100,000+  Free     0
# 10833     4.8      44                619k       1,000+  Free     0
# 10834     4.0       7                2.6M         500+  Free     0
# 10835     NaN       0                9.6M          10+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                           Genres        Last Updated  \
# 0           Everyone                     Art & Design     January 7, 2018
# 1           Everyone        Art & Design;Pretend Play    January 15, 2018
# 2           Everyone                     Art & Design      August 1, 2018
# 3               Teen                     Art & Design        June 8, 2018
# 4           Everyone          Art & Design;Creativity       June 20, 2018
# 5           Everyone                     Art & Design      March 26, 2017
# 6           Everyone                     Art & Design      April 26, 2018
# 7           Everyone                     Art & Design       June 14, 2018
# 8           Everyone                     Art & Design  September 20, 2017
# 9           Everyone          Art & Design;Creativity        July 3, 2018
# 10          Everyone                     Art & Design    October 27, 2017
# 11          Everyone                     Art & Design       July 31, 2018
# 12              Teen                     Art & Design       April 2, 2018
# 13          Everyone                     Art & Design       June 26, 2018
# 14          Everyone                     Art & Design      August 3, 2018
# 15          Everyone                     Art & Design        June 6, 2018
# 16          Everyone                     Art & Design       July 31, 2018
# 17          Everyone                     Art & Design    November 7, 2017
# 18          Everyone                     Art & Design      August 3, 2018
# 19          Everyone                     Art & Design       July 30, 2018
# 20          Everyone                     Art & Design      April 20, 2018
# 21          Everyone                     Art & Design      March 20, 2018
# 22      Everyone 10+                     Art & Design       July 12, 2018
# 23          Everyone  Art & Design;Action & Adventure       March 7, 2018
# 24          Everyone                     Art & Design        July 7, 2018
# 25          Everyone                     Art & Design      April 25, 2018
# 26          Everyone          Art & Design;Creativity    October 11, 2017
# 27          Everyone                     Art & Design      March 21, 2018
# 28          Everyone                     Art & Design       July 12, 2018
# 29          Everyone                     Art & Design     August 22, 2017
# ...              ...                              ...                 ...
# 10811       Everyone                  Auto & Vehicles       July 24, 2018
# 10812       Everyone                        Education       June 13, 2018
# 10813       Everyone                         Business       July 17, 2018
# 10814           Teen                    Entertainment        June 3, 2015
# 10815       Everyone                Books & Reference       July 19, 2018
# 10816       Everyone                         Business      August 6, 2018
# 10817       Everyone                            Tools    October 30, 2015
# 10818       Everyone                          Finance        May 19, 2016
# 10819           Teen                Books & Reference      August 5, 2017
# 10820           Teen                        Education       June 27, 2018
# 10821       Everyone                    Entertainment        May 29, 2018
# 10822       Everyone                     Productivity    December 1, 2017
# 10823       Everyone          Video Players & Editors      April 22, 2018
# 10824       Everyone                          Medical       July 31, 2018
# 10825           Teen                           Social    February 2, 2018
# 10826     Mature 17+                           Social      March 23, 2018
# 10827       Everyone                        Education       June 13, 2018
# 10828       Everyone                           Comics        May 15, 2017
# 10829       Everyone                Books & Reference       June 19, 2016
# 10830       Everyone                 News & Magazines    January 20, 2014
# 10831       Everyone                Maps & Navigation       June 13, 2018
# 10832       Everyone                          Weather   February 16, 2014
# 10833       Everyone                Books & Reference      March 23, 2014
# 10834       Everyone                        Education       June 18, 2017
# 10835       Everyone                         Business  September 29, 2016
# 10836       Everyone                        Education       July 25, 2017
# 10837       Everyone                        Education        July 6, 2018
# 10838       Everyone                          Medical    January 20, 2017
# 10839     Mature 17+                Books & Reference    January 19, 2015
# 10840       Everyone                        Lifestyle       July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# 5                     1.0          2.3 and up
# 6                     1.1        4.0.3 and up
# 7                6.1.61.1          4.2 and up
# 8                   2.9.2          3.0 and up
# 9                     2.8        4.0.3 and up
# 10                  1.0.4          4.1 and up
# 11                 1.0.15          4.0 and up
# 12                    3.8          4.1 and up
# 13                  1.0.4          4.4 and up
# 14                  1.2.3          2.3 and up
# 15                    NaN          4.2 and up
# 16                    3.1          4.1 and up
# 17                    1.0          2.3 and up
# 18                  2.2.5        4.0.3 and up
# 19                  5.5.4          4.1 and up
# 20                    4.0          4.1 and up
# 21                    1.1        4.0.3 and up
# 22                2.2.6.2        4.0.3 and up
# 23                  1.0.0          4.1 and up
# 24                  1.1.3          4.1 and up
# 25                    1.5          3.0 and up
# 26                  1.0.8        4.0.3 and up
# 27                   1.03        4.0.3 and up
# 28                    6.0          2.3 and up
# 29                    1.0          2.3 and up
# ...                   ...                 ...
# 10811               1.3.6         4.4W and up
# 10812              2.0.20        4.0.3 and up
# 10813              2.1.10          4.1 and up
# 10814               1.3.1          3.0 and up
# 10815             7.0.4.6          4.2 and up
# 10816               2.1.8          4.1 and up
# 10817          1.0.612928          5.0 and up
# 10818                 2.3          2.2 and up
# 10819               0.3.4          4.1 and up
# 10820               3.8.0          4.1 and up
# 10821                 1.0        4.0.3 and up
# 10822                   1          4.4 and up
# 10823                 1.0        4.0.3 and up
# 10824               2.2.2          4.4 and up
# 10825                 1.0          4.0 and up
# 10826  Varies with device  Varies with device
# 10827              2.0.20        4.0.3 and up
# 10828               2.0.1          4.0 and up
# 10829                2.96          4.1 and up
# 10830                 1.5          1.6 and up
# 10831           2.0.148.0          4.0 and up
# 10832                 6.0          2.1 and up
# 10833                 0.8          2.2 and up
# 10834               1.0.0          4.1 and up
# 10835               1.1.5          4.0 and up
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
playstore_data.shape
# Out:
# (10841, 13)

# %%
playstore_data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
playstore_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
playstore_data.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
playstore_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
playstore_data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
playstore_data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
import numpy as np                                                 # Implemennts milti-dimensional array and matrices
import pandas_profiling
import matplotlib.pyplot as plt                                    # Plotting library for Python programming language and it's numerical mathematics extension NumPy
import seaborn as sns                                              # Provides a high level interface for drawing attractive and informative statistical graphics
# %matplotlib inline
sns.set()

from subprocess import check_output

# %% [markdown]
# Preprocess profiling

# %%
profile = pandas_profiling.ProfileReport(playstore_data)
profile.to_file(outputfile="playstore_before_preprocessing.html")

# %% [markdown]
# Delete duplicate rows

# %%
playstore_data.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
playstore_data.shape
# Out:
# (10358, 13)

# %% [markdown]
# Find duplicate app names.

# %%
pd.concat(g for _, g in playstore_data.groupby("App") if len(g) > 1)
# Out:
#                                                      App            Category  \
# 3083                             365Scores - Live Scores              SPORTS
# 5415                             365Scores - Live Scores              SPORTS
# 1675                                         8 Ball Pool                GAME
# 1703                                         8 Ball Pool                GAME
# 1755                                         8 Ball Pool                GAME
# 1844                                         8 Ball Pool                GAME
# 1871                                         8 Ball Pool                GAME
# 1970                                         8 Ball Pool                GAME
# 3953                                         8 Ball Pool              SPORTS
# 559                      95Live -SG#1 Live Streaming App              DATING
# 662                      95Live -SG#1 Live Streaming App              DATING
# 920                A&E - Watch Full Episodes of TV Shows       ENTERTAINMENT
# 4991               A&E - Watch Full Episodes of TV Shows              FAMILY
# 3799                       AC - Tips & News for Android™  NEWS_AND_MAGAZINES
# 4928                       AC - Tips & News for Android™  NEWS_AND_MAGAZINES
# 3791                           AP Mobile - Breaking News  NEWS_AND_MAGAZINES
# 5448                           AP Mobile - Breaking News  NEWS_AND_MAGAZINES
# 2771                                                ASOS            SHOPPING
# 2800                                                ASOS            SHOPPING
# 3628   AccuWeather: Daily Forecast & Live Weather Rep...             WEATHER
# 5512   AccuWeather: Daily Forecast & Live Weather Rep...             WEATHER
# 1095                        Acorns - Invest Spare Change             FINANCE
# 1143                        Acorns - Invest Spare Change             FINANCE
# 3452                                Adobe Acrobat Reader        PRODUCTIVITY
# 3524                                Adobe Acrobat Reader        PRODUCTIVITY
# 3895                                Adobe Acrobat Reader        PRODUCTIVITY
# 2814   Adobe Photoshop Express:Photo Editor Collage M...         PHOTOGRAPHY
# 2936   Adobe Photoshop Express:Photo Editor Collage M...         PHOTOGRAPHY
# 1947                                             Agar.io                GAME
# 3880                                             Agar.io                GAME
# ...                                                  ...                 ...
# 4224                           free video calls and chat       COMMUNICATION
# 347                        imo free video calls and chat       COMMUNICATION
# 383                        imo free video calls and chat       COMMUNICATION
# 2663    letgo: Buy & Sell Used Stuff, Cars & Real Estate            SHOPPING
# 4322    letgo: Buy & Sell Used Stuff, Cars & Real Estate            SHOPPING
# 525    muzmatch: Muslim & Arab Singles, Marriage & Da...              DATING
# 673    muzmatch: Muslim & Arab Singles, Marriage & Da...              DATING
# 3492                                              myAT&T        PRODUCTIVITY
# 4593                                              myAT&T        PRODUCTIVITY
# 2331   mySugr: the blood sugar tracker made just for you             MEDICAL
# 6194   mySugr: the blood sugar tracker made just for you             MEDICAL
# 2595              ooVoo Video Calls, Messaging & Stories              SOCIAL
# 2618              ooVoo Video Calls, Messaging & Stories              SOCIAL
# 3334                             osmino Wi-Fi: free WiFi               TOOLS
# 10473                            osmino Wi-Fi: free WiFi               TOOLS
# 1468       realestate.com.au - Buy, Rent & Sell Property      HOUSE_AND_HOME
# 5664       realestate.com.au - Buy, Rent & Sell Property      HOUSE_AND_HOME
# 1659                                          slither.io                GAME
# 1735                                          slither.io                GAME
# 1757                                          slither.io                GAME
# 1891                                          slither.io                GAME
# 4227                                          slither.io                GAME
# 499                       stranger chat - anonymous chat              DATING
# 565                       stranger chat - anonymous chat              DATING
# 2590                         textPlus: Free Text & Calls              SOCIAL
# 2637                         textPlus: Free Text & Calls              SOCIAL
# 2964   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3055   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3652                      wetter.com - Weather and Radar             WEATHER
# 8291                      wetter.com - Weather and Radar             WEATHER
#
#        Rating   Reviews                Size      Installs  Type Price  \
# 3083      4.6    666521                 25M   10,000,000+  Free     0
# 5415      4.6    666246                 25M   10,000,000+  Free     0
# 1675      4.5  14198297                 52M  100,000,000+  Free     0
# 1703      4.5  14198602                 52M  100,000,000+  Free     0
# 1755      4.5  14200344                 52M  100,000,000+  Free     0
# 1844      4.5  14200550                 52M  100,000,000+  Free     0
# 1871      4.5  14201891                 52M  100,000,000+  Free     0
# 1970      4.5  14201604                 52M  100,000,000+  Free     0
# 3953      4.5  14184910                 52M  100,000,000+  Free     0
# 559       4.1      4953                 15M    1,000,000+  Free     0
# 662       4.1      4954                 15M    1,000,000+  Free     0
# 920       4.0     29706                 19M    1,000,000+  Free     0
# 4991      4.0     29708                 19M    1,000,000+  Free     0
# 3799      4.2     23292                 14M    1,000,000+  Free     0
# 4928      4.2     23291                 14M    1,000,000+  Free     0
# 3791      4.5     76677                4.6M    1,000,000+  Free     0
# 5448      4.5     76616                4.6M    1,000,000+  Free     0
# 2771      4.7    181798                 22M   10,000,000+  Free     0
# 2800      4.7    181823                 22M   10,000,000+  Free     0
# 3628      4.4   2053404  Varies with device   50,000,000+  Free     0
# 5512      4.4   2052407  Varies with device   50,000,000+  Free     0
# 1095      4.3     45957  Varies with device    1,000,000+  Free     0
# 1143      4.3     45962  Varies with device    1,000,000+  Free     0
# 3452      4.3   3016297  Varies with device  100,000,000+  Free     0
# 3524      4.3   3016305  Varies with device  100,000,000+  Free     0
# 3895      4.3   3014548  Varies with device  100,000,000+  Free     0
# 2814      4.2    914804  Varies with device   50,000,000+  Free     0
# 2936      4.2    914917  Varies with device   50,000,000+  Free     0
# 1947      4.2   3816799                 32M  100,000,000+  Free     0
# 3880      4.2   3815614                 32M  100,000,000+  Free     0
# ...       ...       ...                 ...           ...   ...   ...
# 4224      4.2    594720  Varies with device   50,000,000+  Free     0
# 347       4.3   4785892                 11M  500,000,000+  Free     0
# 383       4.3   4785988                 11M  500,000,000+  Free     0
# 2663      4.5    973270                 20M   50,000,000+  Free     0
# 4322      4.5    972256                 20M   50,000,000+  Free     0
# 525       3.8      5164                 25M      100,000+  Free     0
# 673       3.8      5168                 25M      100,000+  Free     0
# 3492      3.7     80847  Varies with device   50,000,000+  Free     0
# 4593      3.7     80816  Varies with device   50,000,000+  Free     0
# 2331      4.6     21189                 36M    1,000,000+  Free     0
# 6194      4.6     21187                 35M    1,000,000+  Free     0
# 2595      4.3   1157004                 34M   50,000,000+  Free     0
# 2618      4.3   1157003                 34M   50,000,000+  Free     0
# 3334      4.2    134203                4.1M   10,000,000+  Free     0
# 10473     4.2    134203                4.1M   10,000,000+  Free     0
# 1468      3.8     14653  Varies with device    1,000,000+  Free     0
# 5664      3.8     14657  Varies with device    1,000,000+  Free     0
# 1659      4.4   5234162  Varies with device  100,000,000+  Free     0
# 1735      4.4   5234825  Varies with device  100,000,000+  Free     0
# 1757      4.4   5234810  Varies with device  100,000,000+  Free     0
# 1891      4.4   5235294  Varies with device  100,000,000+  Free     0
# 4227      4.4   5231553  Varies with device  100,000,000+  Free     0
# 499       3.5     13202                6.1M    1,000,000+  Free     0
# 565       3.5     13204                6.1M    1,000,000+  Free     0
# 2590      4.1    382120                 28M   10,000,000+  Free     0
# 2637      4.1    382121                 28M   10,000,000+  Free     0
# 2964      4.4    133825                 34M   10,000,000+  Free     0
# 3055      4.4    133833                 34M   10,000,000+  Free     0
# 3652      4.2    189313                 38M   10,000,000+  Free     0
# 8291      4.2    189310                 38M   10,000,000+  Free     0
#
#       Content Rating            Genres       Last Updated         Current Ver  \
# 3083        Everyone            Sports      July 29, 2018               5.5.9
# 5415        Everyone            Sports      July 29, 2018               5.5.9
# 1675        Everyone            Sports      July 31, 2018               4.0.0
# 1703        Everyone            Sports      July 31, 2018               4.0.0
# 1755        Everyone            Sports      July 31, 2018               4.0.0
# 1844        Everyone            Sports      July 31, 2018               4.0.0
# 1871        Everyone            Sports      July 31, 2018               4.0.0
# 1970        Everyone            Sports      July 31, 2018               4.0.0
# 3953        Everyone            Sports      July 31, 2018               4.0.0
# 559             Teen            Dating     August 1, 2018               8.7.2
# 662             Teen            Dating     August 1, 2018               8.7.2
# 920             Teen     Entertainment      July 16, 2018               3.1.4
# 4991            Teen     Entertainment      July 16, 2018               3.1.4
# 3799    Everyone 10+  News & Magazines       May 24, 2018              3.1.12
# 4928    Everyone 10+  News & Magazines       May 24, 2018              3.1.12
# 3791    Everyone 10+  News & Magazines       May 25, 2017               4.4.3
# 5448    Everyone 10+  News & Magazines       May 25, 2017               4.4.3
# 2771        Everyone          Shopping      July 30, 2018               4.4.9
# 2800        Everyone          Shopping      July 30, 2018               4.4.9
# 3628        Everyone           Weather     August 6, 2018  Varies with device
# 5512        Everyone           Weather     August 2, 2018  Varies with device
# 1095        Everyone           Finance      July 31, 2018  Varies with device
# 1143        Everyone           Finance      July 31, 2018  Varies with device
# 3452        Everyone      Productivity     April 17, 2018  Varies with device
# 3524        Everyone      Productivity     April 17, 2018  Varies with device
# 3895        Everyone      Productivity     April 17, 2018  Varies with device
# 2814        Everyone       Photography      July 22, 2018             5.0.508
# 2936        Everyone       Photography      July 22, 2018             5.0.508
# 1947        Everyone            Action      July 23, 2018               2.2.8
# 3880        Everyone            Action      July 23, 2018               2.2.8
# ...              ...               ...                ...                 ...
# 4224        Everyone     Communication      July 19, 2018         7.3(800241)
# 347         Everyone     Communication       June 8, 2018    9.8.000000010501
# 383         Everyone     Communication       June 8, 2018    9.8.000000010501
# 2663            Teen          Shopping     August 6, 2018               2.4.9
# 4322            Teen          Shopping     August 2, 2018               2.4.8
# 525       Mature 17+            Dating      July 24, 2018             3.8.75a
# 673       Mature 17+            Dating      July 24, 2018             3.8.75a
# 3492        Everyone      Productivity      July 18, 2018  Varies with device
# 4593        Everyone      Productivity      July 18, 2018  Varies with device
# 2331        Everyone           Medical     August 6, 2018              3.52.1
# 6194        Everyone           Medical      July 23, 2018              3.52.0
# 2595        Everyone            Social   October 16, 2017               4.2.1
# 2618        Everyone            Social   October 16, 2017               4.2.1
# 3334        Everyone             Tools     August 6, 2018             6.06.14
# 10473       Everyone             Tools     August 7, 2018             6.06.14
# 1468        Everyone      House & Home      July 16, 2018  Varies with device
# 5664        Everyone      House & Home      July 16, 2018  Varies with device
# 1659        Everyone            Action  November 14, 2017  Varies with device
# 1735        Everyone            Action  November 14, 2017  Varies with device
# 1757        Everyone            Action  November 14, 2017  Varies with device
# 1891        Everyone            Action  November 14, 2017  Varies with device
# 4227        Everyone            Action  November 14, 2017  Varies with device
# 499       Mature 17+            Dating       July 7, 2018               2.4.1
# 565       Mature 17+            Dating       July 7, 2018               2.4.1
# 2590        Everyone            Social      July 26, 2018               7.3.1
# 2637        Everyone            Social      July 26, 2018               7.3.1
# 2964    Everyone 10+            Sports      July 25, 2018              6.17.2
# 3055    Everyone 10+            Sports      July 25, 2018              6.17.2
# 3652        Everyone           Weather     August 6, 2018  Varies with device
# 8291        Everyone           Weather     August 6, 2018  Varies with device
#
#               Android Ver
# 3083           4.1 and up
# 5415           4.1 and up
# 1675         4.0.3 and up
# 1703         4.0.3 and up
# 1755         4.0.3 and up
# 1844         4.0.3 and up
# 1871         4.0.3 and up
# 1970         4.0.3 and up
# 3953         4.0.3 and up
# 559            4.2 and up
# 662            4.2 and up
# 920            4.4 and up
# 4991           4.4 and up
# 3799           4.1 and up
# 4928           4.1 and up
# 3791           4.0 and up
# 5448           4.0 and up
# 2771           4.4 and up
# 2800           4.4 and up
# 3628   Varies with device
# 5512   Varies with device
# 1095   Varies with device
# 1143   Varies with device
# 3452   Varies with device
# 3524   Varies with device
# 3895   Varies with device
# 2814           4.4 and up
# 2936           4.4 and up
# 1947         4.0.3 and up
# 3880         4.0.3 and up
# ...                   ...
# 4224           4.4 and up
# 347            4.0 and up
# 383            4.0 and up
# 2663           4.1 and up
# 4322           4.1 and up
# 525          4.0.3 and up
# 673          4.0.3 and up
# 3492           5.0 and up
# 4593           5.0 and up
# 2331           5.0 and up
# 6194           5.0 and up
# 2595           4.3 and up
# 2618           4.3 and up
# 3334           4.4 and up
# 10473          4.4 and up
# 1468   Varies with device
# 5664   Varies with device
# 1659           2.3 and up
# 1735           2.3 and up
# 1757           2.3 and up
# 1891           2.3 and up
# 4227           2.3 and up
# 499            4.1 and up
# 565            4.1 and up
# 2590           4.1 and up
# 2637           4.1 and up
# 2964           4.4 and up
# 3055           4.4 and up
# 3652   Varies with device
# 8291   Varies with device
#
# [1221 rows x 13 columns]

# %% [markdown]
# These apps seems to be duplicates. So we can safely remove them.

# %%
playstore_data.drop_duplicates(subset="App", keep='first', inplace=True)

# %%
playstore_data.shape
# Out:
# (9660, 13)

# %%
playstore_data[playstore_data['Type'].isnull()] # Fix Type = NaN
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
playstore_data["Type"].fillna("Free", inplace = True)

# %%
playstore_data[playstore_data['Type'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
# Fix Content rating = NaN
playstore_data[playstore_data['Content Rating'].isnull()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
playstore_data['Content Rating'].unique() # Print unique values of Content Rating
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated', nan], dtype=object)

# %%
playstore_data["Content Rating"].fillna("Everyone", inplace = True) # Replace NaN with Everyone

# %%
playstore_data[playstore_data['Content Rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
playstore_data[playstore_data['Current Ver'].isnull()]
# Out:
#                                    App             Category  Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1   20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2    4010
# 6803                         BT Master               FAMILY     NaN       0
# 7333                       Dots puzzle               FAMILY     4.0     179
# 7407                   Calculate My IQ               FAMILY     NaN      44
# 7730                            UFO-CQ                TOOLS     NaN       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     NaN       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# 6322   8.7M    500,000+  Free      0       Everyone              Tools
# 6803   222k        100+  Free      0       Everyone          Education
# 7333    14M     50,000+  Paid  $0.99       Everyone             Puzzle
# 7407   7.2M     10,000+  Free      0       Everyone      Entertainment
# 7730   237k         10+  Paid  $0.99       Everyone              Tools
# 10342  658k      1,000+  Free      0       Everyone  Books & Reference
#
#             Last Updated Current Ver Android Ver
# 15          June 6, 2018         NaN  4.2 and up
# 1553   February 12, 2013         NaN  1.5 and up
# 6322        May 10, 2017         NaN  4.0 and up
# 6803    November 6, 2016         NaN  1.6 and up
# 7333      April 18, 2018         NaN  4.0 and up
# 7407       April 3, 2017         NaN  2.3 and up
# 7730        July 4, 2016         NaN  2.0 and up
# 10342   January 31, 2017         NaN  3.0 and up

# %%
playstore_data.loc[playstore_data.App == 'Learn To Draw Kawaii Characters', 'Current Ver'] = '1.001'

# %%
playstore_data.loc[playstore_data.App == 'Virtual DJ Sound Mixer', 'Current Ver'] = '4'

# %%
playstore_data.loc[playstore_data.App == 'Market Update Helper', 'Current Ver'] = '1'

# %%
playstore_data.loc[playstore_data.App == 'BT Master', 'Current Ver'] = '1'

# %%
playstore_data.loc[playstore_data.App == 'Dots puzzle', 'Current Ver'] = '1'

# %%
playstore_data.loc[playstore_data.App == 'Calculate My IQ', 'Current Ver'] = '1'

# %%
playstore_data.loc[playstore_data.App == 'UFO-CQ', 'Current Ver'] = '1'

# %%
playstore_data.loc[playstore_data.App == 'La Fe de Jesus', 'Current Ver'] = '1'

# %%
playstore_data[playstore_data['Current Ver'].isnull()] # Cleaned Current Ver
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
playstore_data[pd.to_numeric(playstore_data.Reviews, errors='coerce').isnull()] # Find rows with Reviews as string
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone       Everyone  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
playstore_data.loc[playstore_data.App == 'Life Made WI-Fi Touchscreen Photo Frame', 'Android Ver'] = '4.0 and up' # Clean this record

# %%
playstore_data.loc[playstore_data.App == 'Life Made WI-Fi Touchscreen Photo Frame', 'Current Ver'] = '1.0.19'

# %%
playstore_data.loc[playstore_data.App == 'Life Made WI-Fi Touchscreen Photo Frame', 'Last Updated'] = 'February 11, 2018'

# %%
playstore_data.loc[playstore_data.App == 'Life Made WI-Fi Touchscreen Photo Frame', 'Genres'] = 'Lifestyle'

# %%
playstore_data.loc[playstore_data.App == 'Life Made WI-Fi Touchscreen Photo Frame', 'Price'] = '0'

# %%
playstore_data.loc[playstore_data.App == 'Life Made WI-Fi Touchscreen Photo Frame', 'Type'] = 'Free'

# %%
playstore_data.loc[playstore_data.App == 'Life Made WI-Fi Touchscreen Photo Frame', 'Installs'] = '1,000+'

# %%
playstore_data.loc[playstore_data.App == 'Life Made WI-Fi Touchscreen Photo Frame', 'Size'] = '3.0M'

# %%
playstore_data.loc[playstore_data.App == 'Life Made WI-Fi Touchscreen Photo Frame', 'Rating'] = 1.9

# %%
playstore_data.loc[playstore_data.App == 'Life Made WI-Fi Touchscreen Photo Frame', 'Category'] = 'LIFESTYLE'

# %%
playstore_data.loc[playstore_data.App == 'Life Made WI-Fi Touchscreen Photo Frame', 'Reviews'] = '24'

# %%
playstore_data[pd.to_numeric(playstore_data.Reviews, errors='coerce').isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
playstore_data['Reviews Count'] = pd.to_numeric(playstore_data.Reviews, errors='coerce')

# %%
playstore_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver  Reviews Count
# 0  4.0.3 and up            159
# 1  4.0.3 and up            967
# 2  4.0.3 and up          87510
# 3    4.2 and up         215644
# 4    4.4 and up            967

# %%
playstore_data[playstore_data['Rating'].isnull()].shape
# Out:
# (1463, 14)

# %%
playstore_data[playstore_data['Rating'].isnull()]
# Out:
#                                                      App             Category  \
# 23                                Mcqueen Coloring pages       ART_AND_DESIGN
# 113                            Wrinkles and rejuvenation               BEAUTY
# 123                               Manicure - nail design               BEAUTY
# 126                         Skin Care and Natural Beauty               BEAUTY
# 129                  Secrets of beauty, youth and health               BEAUTY
# 130                   Recipes and tips for losing weight               BEAUTY
# 134                        Lady adviser (beauty, health)               BEAUTY
# 163                           Anonymous caller detection  BOOKS_AND_REFERENCE
# 180                  SH-02J Owner's Manual (Android 8.0)  BOOKS_AND_REFERENCE
# 185                       URBANO V 02 instruction manual  BOOKS_AND_REFERENCE
# 227                                       Y! Mobile menu             BUSINESS
# 321    【Ranobbe complete free】 Novelba - Free app tha...               COMICS
# 478                                    Truth or Dare Pro               DATING
# 479      Private Dating, Hide App- Blue for PrivacyHider               DATING
# 480                                 Ad Blocker for SayHi               DATING
# 610                                    Random Video Chat               DATING
# 613                 Random Video Chat App With Strangers               DATING
# 617             Meet With Strangers: Video Chat & Dating               DATING
# 620             Ost. Zombies Cast - New Music and Lyrics               DATING
# 621                                   Dating White Girls               DATING
# 623                                         Geeks Dating               DATING
# 624                          Live chat - free video chat               DATING
# 626                  Fishing Brain & Boating Maps Marine               DATING
# 627                                   CAM5678 Video Chat               DATING
# 628                              Video chat live advices               DATING
# 629                                       chat live chat               DATING
# 630                                    Pet Lovers Dating               DATING
# 631            Friend Find: free chat + flirt dating app               DATING
# 632                                         Latin Dating               DATING
# 635                                          Wifi Mingle               DATING
# ...                                                  ...                  ...
# 10746                                         FP Opgaver                TOOLS
# 10748                                            FP Live        COMMUNICATION
# 10751                                          FP Market               FAMILY
# 10759                                     FP NFC Rewrite                TOOLS
# 10761                             Greek Bible FP (Audio)  BOOKS_AND_REFERENCE
# 10762                                      The FP Shield   NEWS_AND_MAGAZINES
# 10764                                  FP Transportation    AUTO_AND_VEHICLES
# 10769                                        FQ Magazine            LIFESTYLE
# 10772                     FQ Load Board for Transporters             BUSINESS
# 10773                                           FQ India            LIFESTYLE
# 10774                                            Miss FQ   NEWS_AND_MAGAZINES
# 10775                                 FQ - Football Quiz               SPORTS
# 10788    Fountain Live Wallpaper HD – Dubai Wallpaper 3D      PERSONALIZATION
# 10794                                            PopStar               FAMILY
# 10798                               Word Search Tab 1 FR               FAMILY
# 10806                                    SnakeBite911 FR              MEDICAL
# 10807                                          My FR App                TOOLS
# 10808                                 lesparticuliers.fr            LIFESTYLE
# 10811                                        FR Plus 1.6    AUTO_AND_VEHICLES
# 10813                                     DICT.fr Mobile             BUSINESS
# 10816                                 FieldBi FR Offline             BUSINESS
# 10818                               Gold Quote - Gold.fr              FINANCE
# 10821                                            Poop FR               FAMILY
# 10822                                          PLMGSS FR         PRODUCTIVITY
# 10823                                       List iptv FR        VIDEO_PLAYERS
# 10824                                          Cardio-FR              MEDICAL
# 10825                                 Naruto & Boruto FR               SOCIAL
# 10831                           payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10835                                           FR Forms             BUSINESS
# 10838                             Parkinson Exercices FR              MEDICAL
#
#        Rating Reviews   Size  Installs  Type  Price Content Rating  \
# 23        NaN      61   7.0M  100,000+  Free      0       Everyone
# 113       NaN     182   5.7M  100,000+  Free      0   Everyone 10+
# 123       NaN     119   3.7M   50,000+  Free      0       Everyone
# 126       NaN     654   7.4M  100,000+  Free      0           Teen
# 129       NaN      77   2.9M   10,000+  Free      0     Mature 17+
# 130       NaN      35   3.1M   10,000+  Free      0   Everyone 10+
# 134       NaN      30   9.9M   10,000+  Free      0     Mature 17+
# 163       NaN     161   2.7M   10,000+  Free      0       Everyone
# 180       NaN       2   7.2M   50,000+  Free      0       Everyone
# 185       NaN     114   7.3M  100,000+  Free      0       Everyone
# 227       NaN       9   1.2M  100,000+  Free      0       Everyone
# 321       NaN    1330    22M   50,000+  Free      0       Everyone
# 478       NaN       0    20M       50+  Paid  $1.49           Teen
# 479       NaN       0    18k      100+  Paid  $2.99       Everyone
# 480       NaN       4   1.2M      100+  Paid  $3.99           Teen
# 610       NaN       3    16M    1,000+  Free      0     Mature 17+
# 613       NaN       3   4.8M    1,000+  Free      0     Mature 17+
# 617       NaN       2   3.7M      500+  Free      0     Mature 17+
# 620       NaN       1   4.6M      100+  Free      0           Teen
# 621       NaN       0   3.6M       50+  Free      0     Mature 17+
# 623       NaN       0    13M       50+  Free      0     Mature 17+
# 624       NaN       1   8.7M      500+  Free      0     Mature 17+
# 626       NaN       3   6.9M      500+  Free      0       Everyone
# 627       NaN       0    39M      500+  Free      0     Mature 17+
# 628       NaN       0   8.0M      100+  Free      0       Everyone
# 629       NaN      24   3.9M    1,000+  Free      0     Mature 17+
# 630       NaN       0    14M       10+  Free      0     Mature 17+
# 631       NaN      23    11M      100+  Free      0     Mature 17+
# 632       NaN       0    13M       10+  Free      0     Mature 17+
# 635       NaN       0  10.0M       10+  Free      0       Everyone
# ...       ...     ...    ...       ...   ...    ...            ...
# 10746     NaN       9    61M    1,000+  Free      0       Everyone
# 10748     NaN       0   3.3M       10+  Free      0           Teen
# 10751     NaN      24    44k    1,000+  Free      0       Everyone
# 10759     NaN      17    67k    1,000+  Free      0       Everyone
# 10761     NaN       5   8.0M    1,000+  Free      0       Everyone
# 10762     NaN       0    11M       10+  Free      0       Everyone
# 10764     NaN       1   885k        1+  Free      0       Everyone
# 10769     NaN       1    12M      100+  Free      0       Everyone
# 10772     NaN       0   3.9M      100+  Free      0       Everyone
# 10773     NaN       0   8.9M       10+  Free      0       Everyone
# 10774     NaN       0    36M       10+  Free      0       Everyone
# 10775     NaN       1   9.0M        1+  Free      0       Everyone
# 10788     NaN       1    20M      500+  Free      0       Everyone
# 10794     NaN      13   5.7M    1,000+  Free      0       Everyone
# 10798     NaN       0  1020k       50+  Paid  $1.04       Everyone
# 10806     NaN       1    42M      500+  Free      0       Everyone
# 10807     NaN       2   4.2M      100+  Free      0       Everyone
# 10808     NaN      96   1.0M   50,000+  Free      0       Everyone
# 10811     NaN       4   3.9M      100+  Free      0       Everyone
# 10813     NaN      20   2.7M   10,000+  Free      0       Everyone
# 10816     NaN       2   6.8M      100+  Free      0       Everyone
# 10818     NaN      96   1.5M   10,000+  Free      0       Everyone
# 10821     NaN       6   2.5M       50+  Free      0       Everyone
# 10822     NaN       0   3.1M       10+  Free      0       Everyone
# 10823     NaN       1   2.9M      100+  Free      0       Everyone
# 10824     NaN      67    82M   10,000+  Free      0       Everyone
# 10825     NaN       7   7.7M      100+  Free      0           Teen
# 10831     NaN      38   9.8M    5,000+  Free      0       Everyone
# 10835     NaN       0   9.6M       10+  Free      0       Everyone
# 10838     NaN       3   9.5M    1,000+  Free      0       Everyone
#
#                                 Genres        Last Updated Current Ver  \
# 23     Art & Design;Action & Adventure       March 7, 2018       1.0.0
# 113                             Beauty  September 20, 2017         8.0
# 123                             Beauty       July 23, 2018         1.3
# 126                             Beauty       July 17, 2018        1.15
# 129                             Beauty      August 8, 2017         2.0
# 130                             Beauty   December 11, 2017         2.0
# 134                             Beauty    January 24, 2018         3.0
# 163                  Books & Reference       July 13, 2018         1.0
# 180                  Books & Reference       June 15, 2018         3.0
# 185                  Books & Reference      August 7, 2015         1.1
# 227                           Business       April 9, 2018       1.0.5
# 321                             Comics        July 3, 2018       6.1.1
# 478                             Dating   September 1, 2017         1.0
# 479                             Dating       July 25, 2017       1.0.1
# 480                             Dating      August 2, 2018         1.2
# 610                             Dating       July 15, 2018        4.20
# 613                             Dating       July 17, 2018          1.
# 617                             Dating       July 16, 2018          1.
# 620                             Dating       July 20, 2018         1.0
# 621                             Dating       July 20, 2018         1.0
# 623                             Dating       July 10, 2018         1.0
# 624                             Dating       July 23, 2018        3.52
# 626                             Dating       July 23, 2018         1.0
# 627                             Dating       July 13, 2018       5.5.8
# 628                             Dating       July 10, 2018         1.0
# 629                             Dating       July 26, 2018         1.0
# 630                             Dating        July 9, 2018         1.0
# 631                             Dating       July 31, 2018         1.0
# 632                             Dating        July 9, 2018         1.0
# 635                             Dating       July 27, 2018         1.3
# ...                                ...                 ...         ...
# 10746                            Tools        May 31, 2018         1.9
# 10748                    Communication    November 3, 2017       1.2.4
# 10751                        Education       June 17, 2012         1.0
# 10759                            Tools    January 29, 2016         1.1
# 10761                Books & Reference     August 29, 2016       1.0.0
# 10762                 News & Magazines    February 1, 2018       1.1.0
# 10764                  Auto & Vehicles       March 9, 2018      10.0.0
# 10769                        Lifestyle   December 12, 2016         1.0
# 10772                         Business   February 16, 2018       1.1.3
# 10773                        Lifestyle       July 31, 2018       7.2.2
# 10774                 News & Magazines       April 5, 2018         3.8
# 10775                           Sports        May 29, 2018         1.0
# 10788                  Personalization      April 13, 2018         1.0
# 10794                           Casual     January 3, 2018         1.6
# 10798                           Puzzle    February 6, 2012         1.1
# 10806                          Medical     October 9, 2017         1.2
# 10807                            Tools       April 9, 2018  1.283.0037
# 10808                        Lifestyle   November 25, 2014         1.5
# 10811                  Auto & Vehicles       July 24, 2018       1.3.6
# 10813                         Business       July 17, 2018      2.1.10
# 10816                         Business      August 6, 2018       2.1.8
# 10818                          Finance        May 19, 2016         2.3
# 10821                    Entertainment        May 29, 2018         1.0
# 10822                     Productivity    December 1, 2017           1
# 10823          Video Players & Editors      April 22, 2018         1.0
# 10824                          Medical       July 31, 2018       2.2.2
# 10825                           Social    February 2, 2018         1.0
# 10831                Maps & Navigation       June 13, 2018   2.0.148.0
# 10835                         Business  September 29, 2016       1.1.5
# 10838                          Medical    January 20, 2017         1.0
#
#         Android Ver  Reviews Count
# 23       4.1 and up             61
# 113      3.0 and up            182
# 123      4.1 and up            119
# 126      4.1 and up            654
# 129      2.3 and up             77
# 130      3.0 and up             35
# 134      3.0 and up             30
# 163      2.3 and up            161
# 180      6.0 and up              2
# 185      5.1 and up            114
# 227      6.0 and up              9
# 321      4.2 and up           1330
# 478      4.0 and up              0
# 479      4.0 and up              0
# 480    4.0.3 and up              4
# 610    4.0.3 and up              3
# 613      4.0 and up              3
# 617      4.0 and up              2
# 620    4.0.3 and up              1
# 621      4.0 and up              0
# 623      4.1 and up              0
# 624    4.0.3 and up              1
# 626    4.0.3 and up              3
# 627    4.0.3 and up              0
# 628      3.0 and up              0
# 629      4.0 and up             24
# 630      4.1 and up              0
# 631      4.4 and up             23
# 632      4.1 and up              0
# 635      4.4 and up              0
# ...             ...            ...
# 10746  4.0.3 and up              9
# 10748    4.2 and up              0
# 10751    1.6 and up             24
# 10759    4.0 and up             17
# 10761  4.0.3 and up              5
# 10762    4.4 and up              0
# 10764    4.0 and up              1
# 10769    4.1 and up              1
# 10772    5.0 and up              0
# 10773    4.1 and up              0
# 10774    4.4 and up              0
# 10775    5.0 and up              1
# 10788    4.1 and up              1
# 10794    4.3 and up             13
# 10798    3.0 and up              0
# 10806    4.1 and up              1
# 10807  2.3.3 and up              2
# 10808    2.3 and up             96
# 10811   4.4W and up              4
# 10813    4.1 and up             20
# 10816    4.1 and up              2
# 10818    2.2 and up             96
# 10821  4.0.3 and up              6
# 10822    4.4 and up              0
# 10823  4.0.3 and up              1
# 10824    4.4 and up             67
# 10825    4.0 and up              7
# 10831    4.0 and up             38
# 10835    4.0 and up              0
# 10838    2.2 and up              3
#
# [1463 rows x 14 columns]

# %%
category = playstore_data[playstore_data['Rating'].isnull()].iloc[0, 1]
category
# Out:
# 'ART_AND_DESIGN'

# %%
playstore_data[playstore_data.Category == category]['Rating'].median()
# Out:
# 4.4

# %%
def fixRatings():
    for index, row in playstore_data.iterrows():
        if (pd.isnull(row['Rating'])):
            category = row['Category']
            medianRating = playstore_data[playstore_data.Category == category]['Rating'].median()
            print(index, category, medianRating)
            playstore_data.at[index,'Rating'] = medianRating
            
fixRatings()
# Out:
# 23 ART_AND_DESIGN 4.4
# 113 BEAUTY 4.3
# 123 BEAUTY 4.3
# 126 BEAUTY 4.3
# 129 BEAUTY 4.3
# 130 BEAUTY 4.3
# 134 BEAUTY 4.3
# 163 BOOKS_AND_REFERENCE 4.5
# 180 BOOKS_AND_REFERENCE 4.5
# 185 BOOKS_AND_REFERENCE 4.5
# 227 BUSINESS 4.2
# 321 COMICS 4.4
# 478 DATING 4.1
# 479 DATING 4.1
# 480 DATING 4.1
# 610 DATING 4.1
# 613 DATING 4.1
# 617 DATING 4.1
# 620 DATING 4.1
# 621 DATING 4.1
# 623 DATING 4.1
# 624 DATING 4.1
# 626 DATING 4.1
# 627 DATING 4.1
# 628 DATING 4.1
# 629 DATING 4.1
# 630 DATING 4.1
# 631 DATING 4.1
# 632 DATING 4.1
# 635 DATING 4.1
# 637 DATING 4.1
# 638 DATING 4.1
# 639 DATING 4.1
# 641 DATING 4.1
# 642 DATING 4.1
# 643 DATING 4.1
# 644 DATING 4.1
# 647 DATING 4.1
# 648 DATING 4.1
# 649 DATING 4.1
# 650 DATING 4.1
# 651 DATING 4.1
# 652 DATING 4.1
# 653 DATING 4.1
# 658 DATING 4.1
# 659 DATING 4.1
# 660 DATING 4.1
# 669 DATING 4.1
# 698 DATING 4.1
# 704 EDUCATION 4.4
# 1013 EVENTS 4.5
# 1024 EVENTS 4.5
# 1025 EVENTS 4.5
# 1032 EVENTS 4.5
# 1033 EVENTS 4.5
# 1034 EVENTS 4.5
# 1039 EVENTS 4.5
# 1041 EVENTS 4.5
# 1043 EVENTS 4.5
# 1045 EVENTS 4.5
# 1046 EVENTS 4.5
# 1177 FOOD_AND_DRINK 4.3
# 1180 FOOD_AND_DRINK 4.3
# 1455 HOUSE_AND_HOME 4.2
# 1469 HOUSE_AND_HOME 4.2
# 1478 HOUSE_AND_HOME 4.2
# 1484 HOUSE_AND_HOME 4.2
# 1489 HOUSE_AND_HOME 4.2
# 1517 LIBRARIES_AND_DEMO 4.2
# 1519 LIBRARIES_AND_DEMO 4.2
# 1520 LIBRARIES_AND_DEMO 4.2
# 1530 LIBRARIES_AND_DEMO 4.2
# 1534 LIBRARIES_AND_DEMO 4.2
# 1536 LIBRARIES_AND_DEMO 4.2
# 1537 LIBRARIES_AND_DEMO 4.2
# 1539 LIBRARIES_AND_DEMO 4.2
# 1540 LIBRARIES_AND_DEMO 4.2
# 1552 LIBRARIES_AND_DEMO 4.2
# 1557 LIBRARIES_AND_DEMO 4.2
# 1559 LIBRARIES_AND_DEMO 4.2
# 2265 MEDICAL 4.3
# 2280 MEDICAL 4.3
# 2294 MEDICAL 4.3
# 2356 MEDICAL 4.3
# 2390 MEDICAL 4.3
# 2422 MEDICAL 4.3
# 2423 MEDICAL 4.3
# 2424 MEDICAL 4.3
# 2425 MEDICAL 4.3
# 2430 MEDICAL 4.3
# 2431 MEDICAL 4.3
# 2432 MEDICAL 4.3
# 2433 MEDICAL 4.3
# 2434 MEDICAL 4.3
# 2435 MEDICAL 4.3
# 2436 MEDICAL 4.3
# 2437 MEDICAL 4.3
# 2438 MEDICAL 4.3
# 2439 MEDICAL 4.3
# 2440 MEDICAL 4.3
# 2441 MEDICAL 4.3
# 2442 MEDICAL 4.3
# 2443 MEDICAL 4.3
# 2446 MEDICAL 4.3
# 2447 MEDICAL 4.3
# 2449 MEDICAL 4.3
# 2451 MEDICAL 4.3
# 2453 MEDICAL 4.3
# 2456 MEDICAL 4.3
# 2460 MEDICAL 4.3
# 2461 MEDICAL 4.3
# 2462 MEDICAL 4.3
# 2465 MEDICAL 4.3
# 2466 MEDICAL 4.3
# 2467 MEDICAL 4.3
# 2468 MEDICAL 4.3
# 2469 MEDICAL 4.3
# 2470 MEDICAL 4.3
# 2471 MEDICAL 4.3
# 2473 MEDICAL 4.3
# 2474 MEDICAL 4.3
# 2478 MEDICAL 4.3
# 2479 MEDICAL 4.3
# 2480 MEDICAL 4.3
# 2481 MEDICAL 4.3
# 2483 MEDICAL 4.3
# 2485 MEDICAL 4.3
# 2501 MEDICAL 4.3
# 2503 MEDICAL 4.3
# 2540 MEDICAL 4.3
# 3252 TOOLS 4.2
# 3258 TOOLS 4.2
# 3577 PARENTING 4.4
# 3579 PARENTING 4.4
# 3580 PARENTING 4.4
# 3583 PARENTING 4.4
# 3585 PARENTING 4.4
# 3589 PARENTING 4.4
# 3599 PARENTING 4.4
# 3603 PARENTING 4.4
# 3616 PARENTING 4.4
# 3621 PARENTING 4.4
# 3705 VIDEO_PLAYERS 4.2
# 3959 PERSONALIZATION 4.4
# 3985 GAME 4.3
# 4130 TOOLS 4.2
# 4134 FAMILY 4.3
# 4137 PERSONALIZATION 4.4
# 4139 PHOTOGRAPHY 4.3
# 4177 TOOLS 4.2
# 4201 SOCIAL 4.3
# 4218 GAME 4.3
# 4256 SPORTS 4.3
# 4265 COMMUNICATION 4.2
# 4269 GAME 4.3
# 4270 GAME 4.3
# 4273 PRODUCTIVITY 4.3
# 4278 PERSONALIZATION 4.4
# 4303 FAMILY 4.3
# 4307 FAMILY 4.3
# 4308 PRODUCTIVITY 4.3
# 4315 PERSONALIZATION 4.4
# 4431 GAME 4.3
# 4451 PERSONALIZATION 4.4
# 4457 PERSONALIZATION 4.4
# 4459 PERSONALIZATION 4.4
# 4462 PERSONALIZATION 4.4
# 4465 PERSONALIZATION 4.4
# 4471 PERSONALIZATION 4.4
# 4475 PERSONALIZATION 4.4
# 4482 PERSONALIZATION 4.4
# 4485 PERSONALIZATION 4.4
# 4489 FAMILY 4.3
# 4504 PRODUCTIVITY 4.3
# 4520 TOOLS 4.2
# 4532 FAMILY 4.3
# 4537 BOOKS_AND_REFERENCE 4.5
# 4538 FAMILY 4.3
# 4543 BOOKS_AND_REFERENCE 4.5
# 4546 BOOKS_AND_REFERENCE 4.5
# 4548 BOOKS_AND_REFERENCE 4.5
# 4549 FAMILY 4.3
# 4550 FAMILY 4.3
# 4551 FAMILY 4.3
# 4562 PRODUCTIVITY 4.3
# 4564 FAMILY 4.3
# 4565 FAMILY 4.3
# 4697 AUTO_AND_VEHICLES 4.3
# 4776 PERSONALIZATION 4.4
# 4845 MEDICAL 4.3
# 4848 COMMUNICATION 4.2
# 4884 FINANCE 4.3
# 4889 LIFESTYLE 4.2
# 4894 FAMILY 4.3
# 5023 AUTO_AND_VEHICLES 4.3
# 5029 TOOLS 4.2
# 5034 BUSINESS 4.2
# 5050 TRAVEL_AND_LOCAL 4.2
# 5051 MEDICAL 4.3
# 5052 SOCIAL 4.3
# 5056 BUSINESS 4.2
# 5059 SHOPPING 4.3
# 5061 HEALTH_AND_FITNESS 4.5
# 5068 BUSINESS 4.2
# 5072 FAMILY 4.3
# 5086 SPORTS 4.3
# 5088 WEATHER 4.3
# 5090 TOOLS 4.2
# 5093 TOOLS 4.2
# 5096 LIFESTYLE 4.2
# 5098 FAMILY 4.3
# 5099 TOOLS 4.2
# 5100 COMMUNICATION 4.2
# 5101 AUTO_AND_VEHICLES 4.3
# 5106 BOOKS_AND_REFERENCE 4.5
# 5107 PRODUCTIVITY 4.3
# 5109 PRODUCTIVITY 4.3
# 5110 WEATHER 4.3
# 5111 FAMILY 4.3
# 5112 BUSINESS 4.2
# 5113 BUSINESS 4.2
# 5114 PRODUCTIVITY 4.3
# 5115 FINANCE 4.3
# 5116 FAMILY 4.3
# 5119 TOOLS 4.2
# 5120 BUSINESS 4.2
# 5122 FINANCE 4.3
# 5123 BOOKS_AND_REFERENCE 4.5
# 5124 BUSINESS 4.2
# 5126 FAMILY 4.3
# 5127 BUSINESS 4.2
# 5131 MEDICAL 4.3
# 5132 MEDICAL 4.3
# 5134 MEDICAL 4.3
# 5135 MEDICAL 4.3
# 5136 MEDICAL 4.3
# 5140 MEDICAL 4.3
# 5141 MEDICAL 4.3
# 5142 FAMILY 4.3
# 5152 MEDICAL 4.3
# 5154 MEDICAL 4.3
# 5155 FAMILY 4.3
# 5157 MEDICAL 4.3
# 5159 FAMILY 4.3
# 5160 MEDICAL 4.3
# 5161 MEDICAL 4.3
# 5162 MEDICAL 4.3
# 5163 FAMILY 4.3
# 5164 MEDICAL 4.3
# 5165 MEDICAL 4.3
# 5166 HEALTH_AND_FITNESS 4.5
# 5168 MEDICAL 4.3
# 5169 FAMILY 4.3
# 5170 MEDICAL 4.3
# 5171 TOOLS 4.2
# 5172 MEDICAL 4.3
# 5174 MEDICAL 4.3
# 5176 MEDICAL 4.3
# 5177 MEDICAL 4.3
# 5208 PRODUCTIVITY 4.3
# 5213 FAMILY 4.3
# 5217 TOOLS 4.2
# 5218 PHOTOGRAPHY 4.3
# 5229 NEWS_AND_MAGAZINES 4.2
# 5231 MAPS_AND_NAVIGATION 4.2
# 5232 COMMUNICATION 4.2
# 5234 NEWS_AND_MAGAZINES 4.2
# 5240 HOUSE_AND_HOME 4.2
# 5243 PHOTOGRAPHY 4.3
# 5247 AUTO_AND_VEHICLES 4.3
# 5249 SHOPPING 4.3
# 5250 COMMUNICATION 4.2
# 5253 FAMILY 4.3
# 5255 LIFESTYLE 4.2
# 5256 LIFESTYLE 4.2
# 5259 BOOKS_AND_REFERENCE 4.5
# 5262 FOOD_AND_DRINK 4.3
# 5264 FAMILY 4.3
# 5265 PERSONALIZATION 4.4
# 5266 MAPS_AND_NAVIGATION 4.2
# 5269 PERSONALIZATION 4.4
# 5270 PERSONALIZATION 4.4
# 5271 NEWS_AND_MAGAZINES 4.2
# 5274 FAMILY 4.3
# 5281 PERSONALIZATION 4.4
# 5288 GAME 4.3
# 5289 PERSONALIZATION 4.4
# 5290 PERSONALIZATION 4.4
# 5296 PERSONALIZATION 4.4
# 5298 PERSONALIZATION 4.4
# 5300 FAMILY 4.3
# 5301 GAME 4.3
# 5302 PERSONALIZATION 4.4
# 5303 FAMILY 4.3
# 5307 SOCIAL 4.3
# 5407 BUSINESS 4.2
# 5414 MEDICAL 4.3
# 5457 BUSINESS 4.2
# 5461 TOOLS 4.2
# 5480 PERSONALIZATION 4.4
# 5484 PHOTOGRAPHY 4.3
# 5486 FAMILY 4.3
# 5494 FAMILY 4.3
# 5497 BUSINESS 4.2
# 5498 TOOLS 4.2
# 5499 TOOLS 4.2
# 5500 FAMILY 4.3
# 5508 PRODUCTIVITY 4.3
# 5510 SPORTS 4.3
# 5511 HEALTH_AND_FITNESS 4.5
# 5513 FAMILY 4.3
# 5564 FAMILY 4.3
# 5575 NEWS_AND_MAGAZINES 4.2
# 5669 SPORTS 4.3
# 5676 NEWS_AND_MAGAZINES 4.2
# 5677 SOCIAL 4.3
# 5680 FAMILY 4.3
# 5682 LIFESTYLE 4.2
# 5683 FAMILY 4.3
# 5687 FAMILY 4.3
# 5688 LIFESTYLE 4.2
# 5690 FINANCE 4.3
# 5694 FOOD_AND_DRINK 4.3
# 5713 COMMUNICATION 4.2
# 5730 FOOD_AND_DRINK 4.3
# 5734 PERSONALIZATION 4.4
# 5739 BUSINESS 4.2
# 5742 HEALTH_AND_FITNESS 4.5
# 5750 FAMILY 4.3
# 5753 FAMILY 4.3
# 5754 TOOLS 4.2
# 5756 TOOLS 4.2
# 5757 FAMILY 4.3
# 5762 NEWS_AND_MAGAZINES 4.2
# 5771 NEWS_AND_MAGAZINES 4.2
# 5788 GAME 4.3
# 5792 COMMUNICATION 4.2
# 5793 FAMILY 4.3
# 5796 PRODUCTIVITY 4.3
# 5798 BUSINESS 4.2
# 5800 TOOLS 4.2
# 5804 FAMILY 4.3
# 5807 GAME 4.3
# 5809 BUSINESS 4.2
# 5810 PRODUCTIVITY 4.3
# 5812 PERSONALIZATION 4.4
# 5816 TOOLS 4.2
# 5817 LIFESTYLE 4.2
# 5824 GAME 4.3
# 5832 FAMILY 4.3
# 5833 VIDEO_PLAYERS 4.2
# 5834 PERSONALIZATION 4.4
# 5835 FAMILY 4.3
# 5837 FAMILY 4.3
# 5838 PERSONALIZATION 4.4
# 5839 LIFESTYLE 4.2
# 5840 LIFESTYLE 4.2
# 5841 PERSONALIZATION 4.4
# 5843 FAMILY 4.3
# 5845 HEALTH_AND_FITNESS 4.5
# 5846 GAME 4.3
# 5851 BUSINESS 4.2
# 5853 TOOLS 4.2
# 5854 BUSINESS 4.2
# 5855 GAME 4.3
# 5857 BUSINESS 4.2
# 5882 VIDEO_PLAYERS 4.2
# 5891 MAPS_AND_NAVIGATION 4.2
# 5918 TRAVEL_AND_LOCAL 4.2
# 5921 COMMUNICATION 4.2
# 5923 TRAVEL_AND_LOCAL 4.2
# 5924 FAMILY 4.3
# 5925 HEALTH_AND_FITNESS 4.5
# 5927 FAMILY 4.3
# 5942 PRODUCTIVITY 4.3
# 5943 FAMILY 4.3
# 5945 FAMILY 4.3
# 5951 SOCIAL 4.3
# 5967 MAPS_AND_NAVIGATION 4.2
# 5976 LIFESTYLE 4.2
# 5977 FAMILY 4.3
# 5985 VIDEO_PLAYERS 4.2
# 5991 BUSINESS 4.2
# 5992 MEDICAL 4.3
# 5998 BEAUTY 4.3
# 6011 FAMILY 4.3
# 6085 FAMILY 4.3
# 6109 FAMILY 4.3
# 6110 FAMILY 4.3
# 6114 BUSINESS 4.2
# 6117 LIFESTYLE 4.2
# 6118 LIFESTYLE 4.2
# 6122 BUSINESS 4.2
# 6138 PHOTOGRAPHY 4.3
# 6139 NEWS_AND_MAGAZINES 4.2
# 6143 SOCIAL 4.3
# 6145 SOCIAL 4.3
# 6147 FAMILY 4.3
# 6149 FAMILY 4.3
# 6150 FAMILY 4.3
# 6151 AUTO_AND_VEHICLES 4.3
# 6152 PHOTOGRAPHY 4.3
# 6153 VIDEO_PLAYERS 4.2
# 6154 FOOD_AND_DRINK 4.3
# 6157 TOOLS 4.2
# 6158 SOCIAL 4.3
# 6162 SPORTS 4.3
# 6163 VIDEO_PLAYERS 4.2
# 6164 FAMILY 4.3
# 6165 BOOKS_AND_REFERENCE 4.5
# 6170 SPORTS 4.3
# 6172 FAMILY 4.3
# 6173 BUSINESS 4.2
# 6174 TOOLS 4.2
# 6176 NEWS_AND_MAGAZINES 4.2
# 6179 TRAVEL_AND_LOCAL 4.2
# 6182 SHOPPING 4.3
# 6186 NEWS_AND_MAGAZINES 4.2
# 6190 FAMILY 4.3
# 6192 NEWS_AND_MAGAZINES 4.2
# 6199 FOOD_AND_DRINK 4.3
# 6208 NEWS_AND_MAGAZINES 4.2
# 6225 SPORTS 4.3
# 6229 FAMILY 4.3
# 6230 FINANCE 4.3
# 6231 TRAVEL_AND_LOCAL 4.2
# 6233 TRAVEL_AND_LOCAL 4.2
# 6234 FINANCE 4.3
# 6235 FAMILY 4.3
# 6237 SOCIAL 4.3
# 6239 HEALTH_AND_FITNESS 4.5
# 6240 LIFESTYLE 4.2
# 6243 LIFESTYLE 4.2
# 6246 BUSINESS 4.2
# 6250 TRAVEL_AND_LOCAL 4.2
# 6257 SOCIAL 4.3
# 6258 GAME 4.3
# 6259 FAMILY 4.3
# 6260 FOOD_AND_DRINK 4.3
# 6261 FOOD_AND_DRINK 4.3
# 6277 GAME 4.3
# 6278 TOOLS 4.2
# 6291 PRODUCTIVITY 4.3
# 6292 PRODUCTIVITY 4.3
# 6318 BEAUTY 4.3
# 6320 GAME 4.3
# 6325 FAMILY 4.3
# 6328 COMMUNICATION 4.2
# 6329 GAME 4.3
# 6333 SOCIAL 4.3
# 6334 VIDEO_PLAYERS 4.2
# 6335 GAME 4.3
# 6336 LIFESTYLE 4.2
# 6337 FAMILY 4.3
# 6339 BUSINESS 4.2
# 6345 BUSINESS 4.2
# 6357 COMMUNICATION 4.2
# 6360 NEWS_AND_MAGAZINES 4.2
# 6365 BUSINESS 4.2
# 6366 PERSONALIZATION 4.4
# 6367 TOOLS 4.2
# 6377 PRODUCTIVITY 4.3
# 6389 BUSINESS 4.2
# 6393 FINANCE 4.3
# 6394 EVENTS 4.5
# 6399 COMMUNICATION 4.2
# 6425 PHOTOGRAPHY 4.3
# 6428 TOOLS 4.2
# 6430 BUSINESS 4.2
# 6433 PHOTOGRAPHY 4.3
# 6434 WEATHER 4.3
# 6435 MEDICAL 4.3
# 6436 FINANCE 4.3
# 6437 HEALTH_AND_FITNESS 4.5
# 6443 COMMUNICATION 4.2
# 6444 GAME 4.3
# 6445 FINANCE 4.3
# 6456 FAMILY 4.3
# 6460 SOCIAL 4.3
# 6464 BOOKS_AND_REFERENCE 4.5
# 6469 TOOLS 4.2
# 6470 SOCIAL 4.3
# 6473 SHOPPING 4.3
# 6475 MEDICAL 4.3
# 6478 SHOPPING 4.3
# 6479 FOOD_AND_DRINK 4.3
# 6480 FINANCE 4.3
# 6481 PRODUCTIVITY 4.3
# 6482 SPORTS 4.3
# 6483 FAMILY 4.3
# 6487 FAMILY 4.3
# 6488 PRODUCTIVITY 4.3
# 6492 BOOKS_AND_REFERENCE 4.5
# 6499 FAMILY 4.3
# 6502 LIFESTYLE 4.2
# 6508 TOOLS 4.2
# 6518 BUSINESS 4.2
# 6519 PRODUCTIVITY 4.3
# 6527 LIBRARIES_AND_DEMO 4.2
# 6528 COMMUNICATION 4.2
# 6530 BUSINESS 4.2
# 6542 TOOLS 4.2
# 6544 PRODUCTIVITY 4.3
# 6545 PRODUCTIVITY 4.3
# 6555 GAME 4.3
# 6559 FAMILY 4.3
# 6560 FAMILY 4.3
# 6567 LIBRARIES_AND_DEMO 4.2
# 6569 LIFESTYLE 4.2
# 6596 HEALTH_AND_FITNESS 4.5
# 6606 BUSINESS 4.2
# 6613 SHOPPING 4.3
# 6623 TOOLS 4.2
# 6624 EVENTS 4.5
# 6633 COMMUNICATION 4.2
# 6634 HOUSE_AND_HOME 4.2
# 6637 PRODUCTIVITY 4.3
# 6638 SPORTS 4.3
# 6639 TRAVEL_AND_LOCAL 4.2
# 6641 PRODUCTIVITY 4.3
# 6642 NEWS_AND_MAGAZINES 4.2
# 6644 BUSINESS 4.2
# 6653 LIFESTYLE 4.2
# 6657 PERSONALIZATION 4.4
# 6659 FOOD_AND_DRINK 4.3
# 6664 FOOD_AND_DRINK 4.3
# 6665 FOOD_AND_DRINK 4.3
# 6667 SHOPPING 4.3
# 6668 FOOD_AND_DRINK 4.3
# 6669 FAMILY 4.3
# 6670 FOOD_AND_DRINK 4.3
# 6671 SHOPPING 4.3
# 6672 TOOLS 4.2
# 6683 FAMILY 4.3
# 6689 FAMILY 4.3
# 6692 PRODUCTIVITY 4.3
# 6693 MAPS_AND_NAVIGATION 4.2
# 6695 BUSINESS 4.2
# 6696 FAMILY 4.3
# 6699 PERSONALIZATION 4.4
# 6701 BUSINESS 4.2
# 6703 FAMILY 4.3
# 6704 NEWS_AND_MAGAZINES 4.2
# 6706 VIDEO_PLAYERS 4.2
# 6710 FAMILY 4.3
# 6711 PERSONALIZATION 4.4
# 6732 TOOLS 4.2
# 6733 FAMILY 4.3
# 6734 GAME 4.3
# 6736 FAMILY 4.3
# 6738 GAME 4.3
# 6742 COMMUNICATION 4.2
# 6743 NEWS_AND_MAGAZINES 4.2
# 6746 TOOLS 4.2
# 6750 TOOLS 4.2
# 6751 NEWS_AND_MAGAZINES 4.2
# 6753 FAMILY 4.3
# 6755 BUSINESS 4.2
# 6778 NEWS_AND_MAGAZINES 4.2
# 6780 TOOLS 4.2
# 6795 TOOLS 4.2
# 6800 LIBRARIES_AND_DEMO 4.2
# 6801 TOOLS 4.2
# 6803 FAMILY 4.3
# 6804 TOOLS 4.2
# 6805 TOOLS 4.2
# 6808 SPORTS 4.3
# 6809 TOOLS 4.2
# 6815 SHOPPING 4.3
# 6817 TRAVEL_AND_LOCAL 4.2
# 6818 FAMILY 4.3
# 6819 TRAVEL_AND_LOCAL 4.2
# 6821 TRAVEL_AND_LOCAL 4.2
# 6826 LIFESTYLE 4.2
# 6828 BEAUTY 4.3
# 6829 FAMILY 4.3
# 6831 GAME 4.3
# 6832 GAME 4.3
# 6834 FAMILY 4.3
# 6835 GAME 4.3
# 6838 BOOKS_AND_REFERENCE 4.5
# 6839 GAME 4.3
# 6841 GAME 4.3
# 6842 GAME 4.3
# 6843 FAMILY 4.3
# 6844 BOOKS_AND_REFERENCE 4.5
# 6846 GAME 4.3
# 6853 HEALTH_AND_FITNESS 4.5
# 6854 HEALTH_AND_FITNESS 4.5
# 6855 MEDICAL 4.3
# 6857 SHOPPING 4.3
# 6859 BUSINESS 4.2
# 6862 TRAVEL_AND_LOCAL 4.2
# 6864 BUSINESS 4.2
# 6865 MEDICAL 4.3
# 6866 SPORTS 4.3
# 6868 BUSINESS 4.2
# 6869 MAPS_AND_NAVIGATION 4.2
# 6871 LIFESTYLE 4.2
# 6872 MEDICAL 4.3
# 6873 BUSINESS 4.2
# 6875 TRAVEL_AND_LOCAL 4.2
# 6876 BUSINESS 4.2
# 6878 BUSINESS 4.2
# 6879 SPORTS 4.3
# 6880 BUSINESS 4.2
# 6888 BUSINESS 4.2
# 6890 BUSINESS 4.2
# 6893 HEALTH_AND_FITNESS 4.5
# 6904 BOOKS_AND_REFERENCE 4.5
# 6912 TOOLS 4.2
# 6915 BOOKS_AND_REFERENCE 4.5
# 6916 PHOTOGRAPHY 4.3
# 6917 PRODUCTIVITY 4.3
# 6918 PRODUCTIVITY 4.3
# 6928 PRODUCTIVITY 4.3
# 6932 GAME 4.3
# 6933 FAMILY 4.3
# 6937 SPORTS 4.3
# 6938 BUSINESS 4.2
# 6940 PRODUCTIVITY 4.3
# 6941 FAMILY 4.3
# 6950 VIDEO_PLAYERS 4.2
# 6952 FINANCE 4.3
# 6954 TOOLS 4.2
# 6955 FINANCE 4.3
# 6956 TOOLS 4.2
# 6959 FAMILY 4.3
# 6962 HEALTH_AND_FITNESS 4.5
# 6965 GAME 4.3
# 6967 GAME 4.3
# 7034 NEWS_AND_MAGAZINES 4.2
# 7038 FAMILY 4.3
# 7040 NEWS_AND_MAGAZINES 4.2
# 7047 PERSONALIZATION 4.4
# 7049 NEWS_AND_MAGAZINES 4.2
# 7051 SHOPPING 4.3
# 7053 PERSONALIZATION 4.4
# 7056 PRODUCTIVITY 4.3
# 7058 NEWS_AND_MAGAZINES 4.2
# 7060 NEWS_AND_MAGAZINES 4.2
# 7061 NEWS_AND_MAGAZINES 4.2
# 7064 VIDEO_PLAYERS 4.2
# 7073 GAME 4.3
# 7074 TOOLS 4.2
# 7081 FINANCE 4.3
# 7083 BUSINESS 4.2
# 7084 BUSINESS 4.2
# 7087 FAMILY 4.3
# 7092 BUSINESS 4.2
# 7101 PRODUCTIVITY 4.3
# 7114 TOOLS 4.2
# 7116 HEALTH_AND_FITNESS 4.5
# 7117 SHOPPING 4.3
# 7120 HEALTH_AND_FITNESS 4.5
# 7121 FAMILY 4.3
# 7123 HOUSE_AND_HOME 4.2
# 7129 FAMILY 4.3
# 7130 BUSINESS 4.2
# 7133 FAMILY 4.3
# 7135 TOOLS 4.2
# 7138 FINANCE 4.3
# 7140 SPORTS 4.3
# 7141 BUSINESS 4.2
# 7153 PRODUCTIVITY 4.3
# 7154 LIFESTYLE 4.2
# 7156 BUSINESS 4.2
# 7157 NEWS_AND_MAGAZINES 4.2
# 7158 BUSINESS 4.2
# 7160 NEWS_AND_MAGAZINES 4.2
# 7161 LIFESTYLE 4.2
# 7163 LIFESTYLE 4.2
# 7166 TOOLS 4.2
# 7167 FAMILY 4.3
# 7168 LIFESTYLE 4.2
# 7169 FAMILY 4.3
# 7171 SPORTS 4.3
# 7172 LIBRARIES_AND_DEMO 4.2
# 7173 LIFESTYLE 4.2
# 7174 ART_AND_DESIGN 4.4
# 7176 TRAVEL_AND_LOCAL 4.2
# 7180 LIFESTYLE 4.2
# 7181 TOOLS 4.2
# 7182 TRAVEL_AND_LOCAL 4.2
# 7183 AUTO_AND_VEHICLES 4.3
# 7184 NEWS_AND_MAGAZINES 4.2
# 7185 NEWS_AND_MAGAZINES 4.2
# 7188 SPORTS 4.3
# 7189 MEDICAL 4.3
# 7190 BUSINESS 4.2
# 7199 BUSINESS 4.2
# 7202 FAMILY 4.3
# 7203 FINANCE 4.3
# 7208 FAMILY 4.3
# 7211 FAMILY 4.3
# 7214 BUSINESS 4.2
# 7217 FAMILY 4.3
# 7220 FAMILY 4.3
# 7221 LIBRARIES_AND_DEMO 4.2
# 7222 LIFESTYLE 4.2
# 7224 TOOLS 4.2
# 7225 MEDICAL 4.3
# 7226 NEWS_AND_MAGAZINES 4.2
# 7227 PRODUCTIVITY 4.3
# 7228 TRAVEL_AND_LOCAL 4.2
# 7230 PRODUCTIVITY 4.3
# 7231 LIFESTYLE 4.2
# 7232 LIFESTYLE 4.2
# 7233 FAMILY 4.3
# 7234 BUSINESS 4.2
# 7246 PERSONALIZATION 4.4
# 7249 LIFESTYLE 4.2
# 7251 FINANCE 4.3
# 7252 PERSONALIZATION 4.4
# 7255 MEDICAL 4.3
# 7256 PERSONALIZATION 4.4
# 7257 PERSONALIZATION 4.4
# 7259 PERSONALIZATION 4.4
# 7262 PERSONALIZATION 4.4
# 7263 HEALTH_AND_FITNESS 4.5
# 7264 HEALTH_AND_FITNESS 4.5
# 7265 LIFESTYLE 4.2
# 7268 LIFESTYLE 4.2
# 7269 SPORTS 4.3
# 7271 FAMILY 4.3
# 7272 HEALTH_AND_FITNESS 4.5
# 7274 LIFESTYLE 4.2
# 7275 SPORTS 4.3
# 7276 HEALTH_AND_FITNESS 4.5
# 7277 SPORTS 4.3
# 7278 SPORTS 4.3
# 7279 HEALTH_AND_FITNESS 4.5
# 7293 PRODUCTIVITY 4.3
# 7294 PRODUCTIVITY 4.3
# 7296 SPORTS 4.3
# 7305 TOOLS 4.2
# 7306 TOOLS 4.2
# 7308 FAMILY 4.3
# 7311 PRODUCTIVITY 4.3
# 7312 FAMILY 4.3
# 7317 NEWS_AND_MAGAZINES 4.2
# 7318 TOOLS 4.2
# 7322 FAMILY 4.3
# 7332 WEATHER 4.3
# 7335 SPORTS 4.3
# 7339 FAMILY 4.3
# 7342 FAMILY 4.3
# 7343 SOCIAL 4.3
# 7344 COMMUNICATION 4.2
# 7346 BOOKS_AND_REFERENCE 4.5
# 7361 SOCIAL 4.3
# 7370 TOOLS 4.2
# 7371 BUSINESS 4.2
# 7376 LIBRARIES_AND_DEMO 4.2
# 7378 FAMILY 4.3
# 7380 LIFESTYLE 4.2
# 7382 FINANCE 4.3
# 7384 HEALTH_AND_FITNESS 4.5
# 7386 BUSINESS 4.2
# 7387 PRODUCTIVITY 4.3
# 7388 BUSINESS 4.2
# 7389 BUSINESS 4.2
# 7390 PRODUCTIVITY 4.3
# 7391 SHOPPING 4.3
# 7394 VIDEO_PLAYERS 4.2
# 7395 BUSINESS 4.2
# 7396 FAMILY 4.3
# 7400 BUSINESS 4.2
# 7401 TOOLS 4.2
# 7407 FAMILY 4.3
# 7409 PRODUCTIVITY 4.3
# 7410 LIBRARIES_AND_DEMO 4.2
# 7432 BUSINESS 4.2
# 7434 SOCIAL 4.3
# 7440 FAMILY 4.3
# 7445 FOOD_AND_DRINK 4.3
# 7447 BUSINESS 4.2
# 7448 FAMILY 4.3
# 7460 BEAUTY 4.3
# 7472 HEALTH_AND_FITNESS 4.5
# 7476 HEALTH_AND_FITNESS 4.5
# 7481 BUSINESS 4.2
# 7485 COMMUNICATION 4.2
# 7486 LIFESTYLE 4.2
# 7488 TOOLS 4.2
# 7493 HEALTH_AND_FITNESS 4.5
# 7494 FAMILY 4.3
# 7502 PERSONALIZATION 4.4
# 7503 PERSONALIZATION 4.4
# 7504 COMMUNICATION 4.2
# 7505 PERSONALIZATION 4.4
# 7516 SPORTS 4.3
# 7521 PERSONALIZATION 4.4
# 7522 PERSONALIZATION 4.4
# 7526 HEALTH_AND_FITNESS 4.5
# 7528 TOOLS 4.2
# 7529 TOOLS 4.2
# 7531 LIFESTYLE 4.2
# 7532 PERSONALIZATION 4.4
# 7581 TOOLS 4.2
# 7622 FAMILY 4.3
# 7629 FAMILY 4.3
# 7642 GAME 4.3
# 7652 LIFESTYLE 4.2
# 7663 FAMILY 4.3
# 7679 MEDICAL 4.3
# 7681 FAMILY 4.3
# 7691 PRODUCTIVITY 4.3
# 7694 PERSONALIZATION 4.4
# 7702 BUSINESS 4.2
# 7703 FAMILY 4.3
# 7710 LIFESTYLE 4.2
# 7712 SOCIAL 4.3
# 7713 SPORTS 4.3
# 7714 TOOLS 4.2
# 7719 COMMUNICATION 4.2
# 7720 TOOLS 4.2
# 7724 COMMUNICATION 4.2
# 7726 FINANCE 4.3
# 7728 BUSINESS 4.2
# 7730 TOOLS 4.2
# 7732 TRAVEL_AND_LOCAL 4.2
# 7735 PRODUCTIVITY 4.3
# 7737 PRODUCTIVITY 4.3
# 7745 TOOLS 4.2
# 7747 BOOKS_AND_REFERENCE 4.5
# 7748 BUSINESS 4.2
# 7757 BUSINESS 4.2
# 7759 FAMILY 4.3
# 7775 TOOLS 4.2
# 7778 FAMILY 4.3
# 7787 TOOLS 4.2
# 7790 AUTO_AND_VEHICLES 4.3
# 7800 HEALTH_AND_FITNESS 4.5
# 7804 HEALTH_AND_FITNESS 4.5
# 7827 BUSINESS 4.2
# 7832 FAMILY 4.3
# 7843 BOOKS_AND_REFERENCE 4.5
# 7854 MEDICAL 4.3
# 7862 MEDICAL 4.3
# 7873 MEDICAL 4.3
# 7874 FAMILY 4.3
# 7878 MEDICAL 4.3
# 7882 MEDICAL 4.3
# 7884 TOOLS 4.2
# 7888 PRODUCTIVITY 4.3
# 7891 MEDICAL 4.3
# 7893 MEDICAL 4.3
# 7897 MEDICAL 4.3
# 7898 MEDICAL 4.3
# 7901 MEDICAL 4.3
# 7981 BUSINESS 4.2
# 7994 FAMILY 4.3
# 8005 COMMUNICATION 4.2
# 8007 FAMILY 4.3
# 8009 FAMILY 4.3
# 8011 COMMUNICATION 4.2
# 8017 COMMUNICATION 4.2
# 8019 FAMILY 4.3
# 8055 LIFESTYLE 4.2
# 8057 BUSINESS 4.2
# 8060 PRODUCTIVITY 4.3
# 8062 GAME 4.3
# 8065 FAMILY 4.3
# 8066 BUSINESS 4.2
# 8067 PRODUCTIVITY 4.3
# 8068 COMMUNICATION 4.2
# 8069 LIFESTYLE 4.2
# 8070 VIDEO_PLAYERS 4.2
# 8072 PRODUCTIVITY 4.3
# 8076 BUSINESS 4.2
# 8078 BUSINESS 4.2
# 8079 BUSINESS 4.2
# 8080 BUSINESS 4.2
# 8081 BUSINESS 4.2
# 8091 PERSONALIZATION 4.4
# 8093 TOOLS 4.2
# 8094 MAPS_AND_NAVIGATION 4.2
# 8097 COMMUNICATION 4.2
# 8103 FINANCE 4.3
# 8105 FAMILY 4.3
# 8106 NEWS_AND_MAGAZINES 4.2
# 8109 BUSINESS 4.2
# 8110 NEWS_AND_MAGAZINES 4.2
# 8112 BUSINESS 4.2
# 8113 HEALTH_AND_FITNESS 4.5
# 8114 BOOKS_AND_REFERENCE 4.5
# 8119 BOOKS_AND_REFERENCE 4.5
# 8137 BOOKS_AND_REFERENCE 4.5
# 8139 BOOKS_AND_REFERENCE 4.5
# 8140 BOOKS_AND_REFERENCE 4.5
# 8145 BOOKS_AND_REFERENCE 4.5
# 8147 COMMUNICATION 4.2
# 8148 SOCIAL 4.3
# 8150 BOOKS_AND_REFERENCE 4.5
# 8151 BOOKS_AND_REFERENCE 4.5
# 8154 PERSONALIZATION 4.4
# 8155 COMMUNICATION 4.2
# 8160 BOOKS_AND_REFERENCE 4.5
# 8161 BOOKS_AND_REFERENCE 4.5
# 8165 PRODUCTIVITY 4.3
# 8169 LIFESTYLE 4.2
# 8206 FAMILY 4.3
# 8209 NEWS_AND_MAGAZINES 4.2
# 8210 TOOLS 4.2
# 8217 TRAVEL_AND_LOCAL 4.2
# 8218 PRODUCTIVITY 4.3
# 8223 TRAVEL_AND_LOCAL 4.2
# 8225 TOOLS 4.2
# 8232 BOOKS_AND_REFERENCE 4.5
# 8241 PHOTOGRAPHY 4.3
# 8242 TOOLS 4.2
# 8243 MAPS_AND_NAVIGATION 4.2
# 8262 FAMILY 4.3
# 8278 COMICS 4.4
# 8280 FAMILY 4.3
# 8282 TRAVEL_AND_LOCAL 4.2
# 8283 BOOKS_AND_REFERENCE 4.5
# 8318 TOOLS 4.2
# 8319 GAME 4.3
# 8322 MAPS_AND_NAVIGATION 4.2
# 8328 PHOTOGRAPHY 4.3
# 8329 SOCIAL 4.3
# 8330 TOOLS 4.2
# 8331 BUSINESS 4.2
# 8332 SPORTS 4.3
# 8333 FAMILY 4.3
# 8334 SOCIAL 4.3
# 8337 BUSINESS 4.2
# 8338 LIFESTYLE 4.2
# 8339 TOOLS 4.2
# 8340 FINANCE 4.3
# 8341 FAMILY 4.3
# 8342 TOOLS 4.2
# 8344 BUSINESS 4.2
# 8345 TOOLS 4.2
# 8346 PRODUCTIVITY 4.3
# 8348 PRODUCTIVITY 4.3
# 8349 TOOLS 4.2
# 8351 NEWS_AND_MAGAZINES 4.2
# 8354 BUSINESS 4.2
# 8355 LIFESTYLE 4.2
# 8356 EVENTS 4.5
# 8358 COMMUNICATION 4.2
# 8359 PRODUCTIVITY 4.3
# 8384 COMMUNICATION 4.2
# 8389 LIFESTYLE 4.2
# 8390 HEALTH_AND_FITNESS 4.5
# 8393 BUSINESS 4.2
# 8414 FAMILY 4.3
# 8425 LIFESTYLE 4.2
# 8431 BOOKS_AND_REFERENCE 4.5
# 8435 BUSINESS 4.2
# 8488 LIFESTYLE 4.2
# 8489 PERSONALIZATION 4.4
# 8490 FAMILY 4.3
# 8495 PERSONALIZATION 4.4
# 8499 COMMUNICATION 4.2
# 8501 LIFESTYLE 4.2
# 8502 FAMILY 4.3
# 8504 COMMUNICATION 4.2
# 8505 BEAUTY 4.3
# 8506 LIFESTYLE 4.2
# 8509 LIFESTYLE 4.2
# 8510 LIFESTYLE 4.2
# 8548 COMMUNICATION 4.2
# 8556 COMMUNICATION 4.2
# 8562 TRAVEL_AND_LOCAL 4.2
# 8565 TOOLS 4.2
# 8566 NEWS_AND_MAGAZINES 4.2
# 8567 PHOTOGRAPHY 4.3
# 8568 MAPS_AND_NAVIGATION 4.2
# 8573 FINANCE 4.3
# 8575 SHOPPING 4.3
# 8576 TOOLS 4.2
# 8577 TOOLS 4.2
# 8578 PRODUCTIVITY 4.3
# 8579 SOCIAL 4.3
# 8580 GAME 4.3
# 8581 BUSINESS 4.2
# 8583 FAMILY 4.3
# 8588 BUSINESS 4.2
# 8593 PRODUCTIVITY 4.3
# 8597 BUSINESS 4.2
# 8598 BUSINESS 4.2
# 8599 BUSINESS 4.2
# 8600 BOOKS_AND_REFERENCE 4.5
# 8602 BUSINESS 4.2
# 8603 FINANCE 4.3
# 8605 FAMILY 4.3
# 8606 FAMILY 4.3
# 8607 NEWS_AND_MAGAZINES 4.2
# 8612 BUSINESS 4.2
# 8614 NEWS_AND_MAGAZINES 4.2
# 8616 PRODUCTIVITY 4.3
# 8690 PHOTOGRAPHY 4.3
# 8698 FAMILY 4.3
# 8729 TOOLS 4.2
# 8752 PERSONALIZATION 4.4
# 8822 GAME 4.3
# 8825 PRODUCTIVITY 4.3
# 8828 HEALTH_AND_FITNESS 4.5
# 8831 FAMILY 4.3
# 8833 BUSINESS 4.2
# 8834 BUSINESS 4.2
# 8839 BUSINESS 4.2
# 8842 BUSINESS 4.2
# 8849 BUSINESS 4.2
# 8851 LIFESTYLE 4.2
# 8854 FAMILY 4.3
# 8868 MEDICAL 4.3
# 8870 BUSINESS 4.2
# 8871 ART_AND_DESIGN 4.4
# 8872 HEALTH_AND_FITNESS 4.5
# 8873 BUSINESS 4.2
# 8876 PRODUCTIVITY 4.3
# 8877 PERSONALIZATION 4.4
# 8882 SHOPPING 4.3
# 8884 SPORTS 4.3
# 8885 SPORTS 4.3
# 8921 FAMILY 4.3
# 8928 FAMILY 4.3
# 8939 PHOTOGRAPHY 4.3
# 8941 PHOTOGRAPHY 4.3
# 8965 TOOLS 4.2
# 8968 TOOLS 4.2
# 8969 PRODUCTIVITY 4.3
# 8973 COMMUNICATION 4.2
# 8985 NEWS_AND_MAGAZINES 4.2
# 8987 NEWS_AND_MAGAZINES 4.2
# 8988 NEWS_AND_MAGAZINES 4.2
# 8999 FAMILY 4.3
# 9001 BUSINESS 4.2
# 9004 BUSINESS 4.2
# 9009 SOCIAL 4.3
# 9012 PERSONALIZATION 4.4
# 9014 TOOLS 4.2
# 9015 HEALTH_AND_FITNESS 4.5
# 9016 TOOLS 4.2
# 9019 PERSONALIZATION 4.4
# 9020 LIFESTYLE 4.2
# 9021 HEALTH_AND_FITNESS 4.5
# 9025 TOOLS 4.2
# 9030 TOOLS 4.2
# 9043 FAMILY 4.3
# 9047 FAMILY 4.3
# 9052 FAMILY 4.3
# 9053 GAME 4.3
# 9054 FAMILY 4.3
# 9058 COMMUNICATION 4.2
# 9074 HEALTH_AND_FITNESS 4.5
# 9075 LIFESTYLE 4.2
# 9076 PERSONALIZATION 4.4
# 9077 TRAVEL_AND_LOCAL 4.2
# 9083 PHOTOGRAPHY 4.3
# 9087 FAMILY 4.3
# 9096 FAMILY 4.3
# 9097 SHOPPING 4.3
# 9101 FINANCE 4.3
# 9104 FINANCE 4.3
# 9109 GAME 4.3
# 9110 GAME 4.3
# 9113 SOCIAL 4.3
# 9115 FINANCE 4.3
# 9118 HEALTH_AND_FITNESS 4.5
# 9123 FAMILY 4.3
# 9125 FAMILY 4.3
# 9131 SHOPPING 4.3
# 9133 NEWS_AND_MAGAZINES 4.2
# 9136 TOOLS 4.2
# 9137 SOCIAL 4.3
# 9139 PRODUCTIVITY 4.3
# 9148 FAMILY 4.3
# 9180 BUSINESS 4.2
# 9183 SPORTS 4.3
# 9185 BUSINESS 4.2
# 9189 SOCIAL 4.3
# 9190 FAMILY 4.3
# 9195 FINANCE 4.3
# 9198 BUSINESS 4.2
# 9199 EVENTS 4.5
# 9201 LIFESTYLE 4.2
# 9206 BOOKS_AND_REFERENCE 4.5
# 9209 HEALTH_AND_FITNESS 4.5
# 9210 TRAVEL_AND_LOCAL 4.2
# 9224 SOCIAL 4.3
# 9231 BUSINESS 4.2
# 9234 PRODUCTIVITY 4.3
# 9235 LIFESTYLE 4.2
# 9237 VIDEO_PLAYERS 4.2
# 9240 FAMILY 4.3
# 9249 TOOLS 4.2
# 9250 LIFESTYLE 4.2
# 9252 PRODUCTIVITY 4.3
# 9255 BOOKS_AND_REFERENCE 4.5
# 9257 SPORTS 4.3
# 9261 TOOLS 4.2
# 9262 HOUSE_AND_HOME 4.2
# 9264 PRODUCTIVITY 4.3
# 9271 FAMILY 4.3
# 9284 TRAVEL_AND_LOCAL 4.2
# 9291 FAMILY 4.3
# 9294 PHOTOGRAPHY 4.3
# 9296 FAMILY 4.3
# 9298 COMMUNICATION 4.2
# 9299 BUSINESS 4.2
# 9300 PRODUCTIVITY 4.3
# 9302 FAMILY 4.3
# 9306 TOOLS 4.2
# 9309 FAMILY 4.3
# 9310 GAME 4.3
# 9312 SPORTS 4.3
# 9319 BUSINESS 4.2
# 9320 BUSINESS 4.2
# 9321 BUSINESS 4.2
# 9322 FAMILY 4.3
# 9324 PRODUCTIVITY 4.3
# 9329 EVENTS 4.5
# 9330 SOCIAL 4.3
# 9331 FINANCE 4.3
# 9333 TOOLS 4.2
# 9337 TRAVEL_AND_LOCAL 4.2
# 9346 FAMILY 4.3
# 9367 FAMILY 4.3
# 9370 FINANCE 4.3
# 9371 BUSINESS 4.2
# 9373 FAMILY 4.3
# 9409 HEALTH_AND_FITNESS 4.5
# 9410 FAMILY 4.3
# 9412 COMMUNICATION 4.2
# 9414 FAMILY 4.3
# 9417 BUSINESS 4.2
# 9418 PRODUCTIVITY 4.3
# 9419 FAMILY 4.3
# 9421 TOOLS 4.2
# 9423 FAMILY 4.3
# 9431 FAMILY 4.3
# 9448 NEWS_AND_MAGAZINES 4.2
# 9453 FAMILY 4.3
# 9458 TOOLS 4.2
# 9459 LIFESTYLE 4.2
# 9460 BUSINESS 4.2
# 9466 SHOPPING 4.3
# 9481 HEALTH_AND_FITNESS 4.5
# 9502 FAMILY 4.3
# 9504 FAMILY 4.3
# 9509 FAMILY 4.3
# 9514 COMMUNICATION 4.2
# 9515 TOOLS 4.2
# 9519 FAMILY 4.3
# 9521 FAMILY 4.3
# 9527 FAMILY 4.3
# 9532 TRAVEL_AND_LOCAL 4.2
# 9548 NEWS_AND_MAGAZINES 4.2
# 9550 TRAVEL_AND_LOCAL 4.2
# 9557 FAMILY 4.3
# 9567 GAME 4.3
# 9612 FAMILY 4.3
# 9648 COMMUNICATION 4.2
# 9651 SOCIAL 4.3
# 9652 BUSINESS 4.2
# 9653 BUSINESS 4.2
# 9654 BUSINESS 4.2
# 9655 HEALTH_AND_FITNESS 4.5
# 9656 BUSINESS 4.2
# 9657 HEALTH_AND_FITNESS 4.5
# 9658 BUSINESS 4.2
# 9660 BUSINESS 4.2
# 9662 LIFESTYLE 4.2
# 9663 BUSINESS 4.2
# 9664 FAMILY 4.3
# 9665 BUSINESS 4.2
# 9666 BUSINESS 4.2
# 9669 FAMILY 4.3
# 9670 TRAVEL_AND_LOCAL 4.2
# 9672 FAMILY 4.3
# 9675 FINANCE 4.3
# 9679 BOOKS_AND_REFERENCE 4.5
# 9691 FINANCE 4.3
# 9692 PRODUCTIVITY 4.3
# 9693 BUSINESS 4.2
# 9698 PRODUCTIVITY 4.3
# 9699 EVENTS 4.5
# 9700 FAMILY 4.3
# 9703 TOOLS 4.2
# 9704 MEDICAL 4.3
# 9706 LIFESTYLE 4.2
# 9707 TOOLS 4.2
# 9713 AUTO_AND_VEHICLES 4.3
# 9714 FAMILY 4.3
# 9715 MEDICAL 4.3
# 9719 MEDICAL 4.3
# 9722 FAMILY 4.3
# 9727 SHOPPING 4.3
# 9730 BUSINESS 4.2
# 9739 LIFESTYLE 4.2
# 9757 FAMILY 4.3
# 9772 MEDICAL 4.3
# 9777 BOOKS_AND_REFERENCE 4.5
# 9782 MEDICAL 4.3
# 9820 COMMUNICATION 4.2
# 9834 FOOD_AND_DRINK 4.3
# 9866 COMMUNICATION 4.2
# 9874 PERSONALIZATION 4.4
# 9878 FAMILY 4.3
# 9882 FAMILY 4.3
# 9884 GAME 4.3
# 9889 PERSONALIZATION 4.4
# 9893 LIBRARIES_AND_DEMO 4.2
# 9896 BUSINESS 4.2
# 9898 GAME 4.3
# 9902 FAMILY 4.3
# 9903 NEWS_AND_MAGAZINES 4.2
# 9905 FINANCE 4.3
# 9907 BUSINESS 4.2
# 9909 BUSINESS 4.2
# 9910 BOOKS_AND_REFERENCE 4.5
# 9912 FINANCE 4.3
# 9913 COMMUNICATION 4.2
# 9914 BUSINESS 4.2
# 9915 LIFESTYLE 4.2
# 9916 BOOKS_AND_REFERENCE 4.5
# 9917 FINANCE 4.3
# 9918 LIFESTYLE 4.2
# 9919 SHOPPING 4.3
# 9920 FAMILY 4.3
# 9924 BUSINESS 4.2
# 9925 SOCIAL 4.3
# 9927 BUSINESS 4.2
# 9928 BUSINESS 4.2
# 9929 PRODUCTIVITY 4.3
# 9930 NEWS_AND_MAGAZINES 4.2
# 9931 SPORTS 4.3
# 9934 LIFESTYLE 4.2
# 9935 MAPS_AND_NAVIGATION 4.2
# 9937 BUSINESS 4.2
# 9938 BUSINESS 4.2
# 9956 AUTO_AND_VEHICLES 4.3
# 9962 HOUSE_AND_HOME 4.2
# 9964 AUTO_AND_VEHICLES 4.3
# 9971 FAMILY 4.3
# 9972 FAMILY 4.3
# 9980 LIFESTYLE 4.2
# 9989 SHOPPING 4.3
# 9990 BUSINESS 4.2
# 9992 NEWS_AND_MAGAZINES 4.2
# 9993 BOOKS_AND_REFERENCE 4.5
# 9994 BUSINESS 4.2
# 9995 FINANCE 4.3
# 9997 BUSINESS 4.2
# 9999 BUSINESS 4.2
# 10000 TOOLS 4.2
# 10002 GAME 4.3
# 10004 HEALTH_AND_FITNESS 4.5
# 10007 TOOLS 4.2
# 10009 NEWS_AND_MAGAZINES 4.2
# 10053 PRODUCTIVITY 4.3
# 10069 SOCIAL 4.3
# 10078 PRODUCTIVITY 4.3
# 10079 FAMILY 4.3
# 10080 BUSINESS 4.2
# 10081 BUSINESS 4.2
# 10083 FINANCE 4.3
# 10084 BUSINESS 4.2
# 10085 BUSINESS 4.2
# 10089 BUSINESS 4.2
# 10090 BUSINESS 4.2
# 10094 BUSINESS 4.2
# 10097 BUSINESS 4.2
# 10099 SPORTS 4.3
# 10101 SOCIAL 4.3
# 10102 PRODUCTIVITY 4.3
# 10103 BUSINESS 4.2
# 10104 BUSINESS 4.2
# 10105 EVENTS 4.5
# 10106 SHOPPING 4.3
# 10108 SOCIAL 4.3
# 10109 COMMUNICATION 4.2
# 10110 FAMILY 4.3
# 10119 HOUSE_AND_HOME 4.2
# 10169 COMMUNICATION 4.2
# 10176 SPORTS 4.3
# 10180 FAMILY 4.3
# 10183 FAMILY 4.3
# 10184 MEDICAL 4.3
# 10185 FINANCE 4.3
# 10187 FAMILY 4.3
# 10214 SOCIAL 4.3
# 10232 SOCIAL 4.3
# 10236 BUSINESS 4.2
# 10256 NEWS_AND_MAGAZINES 4.2
# 10265 MAPS_AND_NAVIGATION 4.2
# 10299 TOOLS 4.2
# 10311 PHOTOGRAPHY 4.3
# 10314 HEALTH_AND_FITNESS 4.5
# 10328 FAMILY 4.3
# 10329 FAMILY 4.3
# 10330 FAMILY 4.3
# 10331 FINANCE 4.3
# 10332 FAMILY 4.3
# 10333 TRAVEL_AND_LOCAL 4.2
# 10334 TOOLS 4.2
# 10337 HEALTH_AND_FITNESS 4.5
# 10338 PERSONALIZATION 4.4
# 10339 PERSONALIZATION 4.4
# 10342 BOOKS_AND_REFERENCE 4.5
# 10344 TOOLS 4.2
# 10346 BOOKS_AND_REFERENCE 4.5
# 10347 FOOD_AND_DRINK 4.3
# 10348 HOUSE_AND_HOME 4.2
# 10350 BUSINESS 4.2
# 10351 FAMILY 4.3
# 10352 SOCIAL 4.3
# 10354 TRAVEL_AND_LOCAL 4.2
# 10355 SPORTS 4.3
# 10356 FAMILY 4.3
# 10358 PERSONALIZATION 4.4
# 10359 BOOKS_AND_REFERENCE 4.5
# 10361 FINANCE 4.3
# 10364 FAMILY 4.3
# 10365 FAMILY 4.3
# 10366 FAMILY 4.3
# 10367 GAME 4.3
# 10368 TOOLS 4.2
# 10369 FAMILY 4.3
# 10377 FAMILY 4.3
# 10399 MEDICAL 4.3
# 10401 PERSONALIZATION 4.4
# 10402 HEALTH_AND_FITNESS 4.5
# 10403 PERSONALIZATION 4.4
# 10404 FAMILY 4.3
# 10411 FAMILY 4.3
# 10413 PERSONALIZATION 4.4
# 10414 FAMILY 4.3
# 10415 PERSONALIZATION 4.4
# 10417 FINANCE 4.3
# 10418 FAMILY 4.3
# 10421 FAMILY 4.3
# 10422 FAMILY 4.3
# 10425 TOOLS 4.2
# 10427 FAMILY 4.3
# 10432 COMMUNICATION 4.2
# 10433 FAMILY 4.3
# 10439 COMMUNICATION 4.2
# 10483 PERSONALIZATION 4.4
# 10485 TOOLS 4.2
# 10488 TOOLS 4.2
# 10494 PERSONALIZATION 4.4
# 10495 PERSONALIZATION 4.4
# 10496 PERSONALIZATION 4.4
# 10497 PERSONALIZATION 4.4
# 10499 PERSONALIZATION 4.4
# 10501 PERSONALIZATION 4.4
# 10510 TOOLS 4.2
# 10517 TOOLS 4.2
# 10519 VIDEO_PLAYERS 4.2
# 10524 GAME 4.3
# 10525 SPORTS 4.3
# 10528 SPORTS 4.3
# 10530 SPORTS 4.3
# 10532 SPORTS 4.3
# 10533 SPORTS 4.3
# 10534 SPORTS 4.3
# 10535 SPORTS 4.3
# 10536 SPORTS 4.3
# 10537 SPORTS 4.3
# 10538 SPORTS 4.3
# 10539 SPORTS 4.3
# 10541 SPORTS 4.3
# 10542 SPORTS 4.3
# 10543 SPORTS 4.3
# 10544 SPORTS 4.3
# 10545 SPORTS 4.3
# 10546 SPORTS 4.3
# 10547 SPORTS 4.3
# 10548 SPORTS 4.3
# 10550 SPORTS 4.3
# 10551 SPORTS 4.3
# 10553 PRODUCTIVITY 4.3
# 10555 SPORTS 4.3
# 10557 SPORTS 4.3
# 10558 SPORTS 4.3
# 10559 SPORTS 4.3
# 10560 SPORTS 4.3
# 10561 SPORTS 4.3
# 10563 SPORTS 4.3
# 10565 SPORTS 4.3
# 10567 SPORTS 4.3
# 10605 EVENTS 4.5
# 10606 PRODUCTIVITY 4.3
# 10608 TRAVEL_AND_LOCAL 4.2
# 10612 WEATHER 4.3
# 10618 FAMILY 4.3
# 10622 PRODUCTIVITY 4.3
# 10625 WEATHER 4.3
# 10626 LIFESTYLE 4.2
# 10627 WEATHER 4.3
# 10631 TRAVEL_AND_LOCAL 4.2
# 10650 BOOKS_AND_REFERENCE 4.5
# 10651 BOOKS_AND_REFERENCE 4.5
# 10653 FAMILY 4.3
# 10654 PERSONALIZATION 4.4
# 10657 PERSONALIZATION 4.4
# 10658 PERSONALIZATION 4.4
# 10660 PERSONALIZATION 4.4
# 10661 BOOKS_AND_REFERENCE 4.5
# 10662 BOOKS_AND_REFERENCE 4.5
# 10664 BOOKS_AND_REFERENCE 4.5
# 10668 BOOKS_AND_REFERENCE 4.5
# 10669 BOOKS_AND_REFERENCE 4.5
# 10670 COMMUNICATION 4.2
# 10672 COMMUNICATION 4.2
# 10674 BOOKS_AND_REFERENCE 4.5
# 10676 TOOLS 4.2
# 10692 COMMUNICATION 4.2
# 10693 COMMUNICATION 4.2
# 10694 COMMUNICATION 4.2
# 10695 COMMUNICATION 4.2
# 10696 COMMUNICATION 4.2
# 10698 COMMUNICATION 4.2
# 10699 FINANCE 4.3
# 10700 COMMUNICATION 4.2
# 10701 FAMILY 4.3
# 10702 BUSINESS 4.2
# 10704 COMMUNICATION 4.2
# 10705 BUSINESS 4.2
# 10708 BUSINESS 4.2
# 10709 COMMUNICATION 4.2
# 10734 COMMUNICATION 4.2
# 10735 FAMILY 4.3
# 10736 BUSINESS 4.2
# 10744 FINANCE 4.3
# 10745 FINANCE 4.3
# 10746 TOOLS 4.2
# 10748 COMMUNICATION 4.2
# 10751 FAMILY 4.3
# 10759 TOOLS 4.2
# 10761 BOOKS_AND_REFERENCE 4.5
# 10762 NEWS_AND_MAGAZINES 4.2
# 10764 AUTO_AND_VEHICLES 4.3
# 10769 LIFESTYLE 4.2
# 10772 BUSINESS 4.2
# 10773 LIFESTYLE 4.2
# 10774 NEWS_AND_MAGAZINES 4.2
# 10775 SPORTS 4.3
# 10788 PERSONALIZATION 4.4
# 10794 FAMILY 4.3
# 10798 FAMILY 4.3
# 10806 MEDICAL 4.3
# 10807 TOOLS 4.2
# 10808 LIFESTYLE 4.2
# 10811 AUTO_AND_VEHICLES 4.3
# 10813 BUSINESS 4.2
# 10816 BUSINESS 4.2
# 10818 FINANCE 4.3
# 10821 FAMILY 4.3
# 10822 PRODUCTIVITY 4.3
# 10823 VIDEO_PLAYERS 4.2
# 10824 MEDICAL 4.3
# 10825 SOCIAL 4.3
# 10831 MAPS_AND_NAVIGATION 4.2
# 10835 BUSINESS 4.2
# 10838 MEDICAL 4.3

# %%
playstore_data[playstore_data['Rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, Reviews Count]
# Index: []

# %%
getAndroidVersion = lambda x: str(x)[0:1] if (str(x)[0].isdigit()) else x # Get Android major version support
playstore_data['Android Ver 4'] = playstore_data['Android Ver'].map(getAndroidVersion)
playstore_data['Android Ver 4'].head()
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# Name: Android Ver 4, dtype: object

# %%
playstore_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver  Reviews Count Android Ver 4
# 0  4.0.3 and up            159             4
# 1  4.0.3 and up            967             4
# 2  4.0.3 and up          87510             4
# 3    4.2 and up         215644             4
# 4    4.4 and up            967             4

# %%
installsToCount = lambda x:int(x.replace(',', '').replace('+', '')) # Create Installs Count
playstore_data['Installs Count'] = playstore_data['Installs'].map(installsToCount)

# %%
getLastUpdatedYear = lambda x:int(x[-4:]) # Get last updated year
playstore_data['Last Updated Year'] = playstore_data['Last Updated'].map(getLastUpdatedYear)

# %%
getSizeNum = lambda x: float(x.replace('M', '')) if (x.endswith('M')) else -1 # if endswith M get the size value
playstore_data['Size Num'] = playstore_data['Size'].map(getSizeNum)

# %%
getMajorVersion = lambda x: int(x[0:1]) if (x[0].isdigit()) else -1 # get app major version
playstore_data['Major Ver'] = playstore_data['Current Ver'].map(getMajorVersion)
playstore_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver  Reviews Count Android Ver 4  Installs Count  \
# 0  4.0.3 and up            159             4           10000
# 1  4.0.3 and up            967             4          500000
# 2  4.0.3 and up          87510             4         5000000
# 3    4.2 and up         215644             4        50000000
# 4    4.4 and up            967             4          100000
#
#    Last Updated Year  Size Num  Major Ver
# 0               2018      19.0          1
# 1               2018      14.0          2
# 2               2018       8.7          1
# 3               2018      25.0         -1
# 4               2018       2.8          1

# %%
# Post Pandas profiling
profile = pandas_profiling.ProfileReport(playstore_data)
profile.to_file(outputfile="playstore_after_preprocessing.html")

# %%
# Import SNS
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Q1 Find top 5 categories with highest median install count

# %%
# Q1 1 - Bar plot with x=Category, y=median installs count. Plot only top 5 cats by median
from numpy import median
top_5_downloaded_categories = playstore_data.groupby(playstore_data.Category)[['Installs Count']].median().sort_values('Installs Count', ascending=False).iloc[:7].index
sns.barplot(x='Category', y='Installs Count', data=playstore_data, estimator=median, order=top_5_downloaded_categories)
plt.xticks(rotation=90)
plt.show
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Q1 2 - Box plot to see distribution of downloads. Plot only top 5 cats by median
sns.catplot(x='Category', y='Installs Count', data=playstore_data, estimator=median, order=top_5_downloaded_categories, kind='box', sym='')
plt.xticks(rotation=90)
plt.ticklabel_format(style='plain', axis='y')
plt.show
# Video players and games have quite a few outliers
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Q2 Is low OS support any deciding factor for download count
# Strip plot OS vs installs count
sns.stripplot(x="Android Ver 4", y="Installs Count", data=playstore_data)
plt.ticklabel_format(style='plain', axis='y')
plt.show
# Support for 4 and above Android version gives more downloads.
# A lot of apps are providing app with multiple OS support as well and they have highest downloads.
# Low OS support doesn't guarantee more downloads. And most probably low OS support apps might be abandoned apps.
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Q3 Do paid apps have comparable download count with free apps

# %%
# Q3 1 Check count of free and paid apps in the given data
sns.countplot(x="Type", data=playstore_data)
# Less than 10% of the apps are paid in the given data and this is a likely trend in Google playstore also.

# %%
# Q3 2 Check installs count of free and paid apps
# ax = sns.violinplot(x="Type", y="Installs Count", data=playstore_data, inner=None, color=".8")
ax = sns.catplot(x="Type", y="Installs Count", data=playstore_data, row = 'Category', jitter=True)
plt.ticklabel_format(style='plain', axis='y')
plt.show
# Except Social category, in all categories free apps dominate the installs count.
# In Social category, paid apps have slight comparable installs count with free apps.
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Q4 Is app size influencing download count
sns.scatterplot(x='Size Num', y='Installs Count', hue='Android Ver 4', data=playstore_data)
plt.xticks(rotation=90)
plt.ticklabel_format(style='plain', axis='y')
plt.show
# At a high level, it doesn't seem that app count matters much
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.scatterplot(x='Size Num', y='Installs Count', hue='Android Ver 4', data=playstore_data[playstore_data['Size Num'] < 20])
plt.xticks(rotation=90)
plt.ticklabel_format(style='plain', axis='y')
plt.show
# Though density reduces a lot as size increases, there are more downloads for apps with higher size.
# App quality might increase app size.
# This proves that people don't mind to install apps with higher size, if the app quality is good.
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.jointplot(x='Size Num', y='Installs Count', kind="hex", data=playstore_data[playstore_data['Size Num'] <= 10]);
plt.ticklabel_format(style='plain', axis='y')
plt.show
# There are a lot of apps with less app size and decent installs count. But these apps are not the highest download apps.
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Q5 How content rating affects download count.
ax = sns.catplot(x="Content Rating", y="Installs Count", data=playstore_data, jitter=True)
plt.xticks(rotation=90)
plt.ticklabel_format(style='plain', axis='y')
plt.show
# Clearly family safe apps are most number of downloads.
# Interesting Teen apps have more download compared to 'Everyone 10+' apps.
# To have more record number of downloads, app content has to be family safe.
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Q5 How size is distributed among top 7 categories
sns.catplot(x='Category', y='Size Num', data=playstore_data, estimator=median, order=top_5_downloaded_categories, kind='point')
plt.xticks(rotation=90)
plt.show
# Games have highest size among top categories followed by entertainment and shopping
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Q7 How Content Rating is distributed among top 7 categories
sns.countplot(x='Category', data=playstore_data, order = top_5_downloaded_categories, hue='Content Rating')
plt.xticks(rotation=90)
plt.show
# All top categories have family safe apps except entertainment.
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Q8 Do apps with high review count have high download count?
sns.scatterplot(x='Reviews Count', y='Installs Count', data=playstore_data[playstore_data['Installs Count'] < 200000000]);
plt.ticklabel_format(style='plain', axis='y')
plt.show
# Apps with high reviews count have high download count.
# But it can be seen as download count influencing review count primarily.
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Q9 Do recently downloaded app have high download count
sns.catplot(x = 'Last Updated Year', y = 'Installs Count', data=playstore_data)
plt.ticklabel_format(style='plain', axis='y')
plt.show
# It clearly shows that people tend use recently updated apps and uninstall outdated apps.
# As last updated year gets older, the install count is decreasing
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Q10 Does download count increase with app maturity?
sns.scatterplot(x = 'Major Ver', y = 'Installs Count', data=playstore_data[playstore_data['Installs Count']<200000000], hue = 'Last Updated Year')
plt.ticklabel_format(style='plain', axis='y')
plt.show
# This is not necessarily true. Also major ver may not exactly imply app maturity.
# Apps with recent updates even though not so mature have high downloads.
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
